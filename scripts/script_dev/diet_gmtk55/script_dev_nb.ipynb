# %%
import jax.numpy as jnp
import jax
import equinox as eqx
import optax
import numpy as np
from pyscf import dft, scf, gto, cc
from pyscfad import dft as dft_ad
from pyscfad import gto as gto_ad
from pyscfad import scf as scf_ad
from functools import partial
import pylibxc
import pyscfad.dft as dftad
from jax import custom_jvp
jax.config.update("jax_enable_x64", True) #Enables 64 bit precision
from ase.io import read
import pyscfad, pyscf
from xcquinox import net, xc
from xcquinox.loss import compute_loss_mae
from xcquinox.train import Pretrainer, Optimizer
from xcquinox.utils import gen_grid_s, PBE_Fx, PBE_Fc, calculate_stats, lda_x, pw92c_unpolarized
from xcquinox.pyscf import eval_xc_gga_j2
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
pyscfad.__version__, pyscf.__version__
# Out:
# ('0.1.9', '2.9.0')

# %%
DIET_TRAJECTORY_PATH = "/home/awills/Documents/Research/xcquinox/scripts/script_data/dietgmtkn55-50/diet50.traj"

traj = read(DIET_TRAJECTORY_PATH, ':')
print("Trajectory loaded in.")
print("Printing information...")    
for idx, at in enumerate(traj):
    print(20*'=')
    print(idx, at)
    print(at.info)
    print(at.get_chemical_symbols())
    print(at.positions)
# Out:
# Trajectory loaded in.
# Printing information...
# ====================
# 0 Atoms(symbols='FNH3', pbc=False)
# {'spin': 0, 'subset': 'AHB21', 'subsetind': 0, 'species': 1, 'count': 1, 'charge': -1, 'refweight': 2.53, 'refen': -17.79, 'energy': -17.79}
# ['F', 'N', 'H', 'H', 'H']
# [[-0.20512  1.19195 -0.69629]
#  [-1.07147 -0.00913  1.50279]
#  [-0.61757 -0.91698  1.47415]
#  [-0.6009   0.48688  2.25356]
#  [-0.76307  0.48318  0.60817]]
# ====================
# 1 Atoms(symbols='F', pbc=False)
# {'spin': 0, 'subset': 'AHB21', 'subsetind': 0, 'species': '1A', 'count': -1, 'charge': -1, 'refweight': 2.53, 'refen': -17.79, 'energy': -17.79}
# ['F']
# [[-0.20512  1.19195 -0.69629]]
# ====================
# 2 Atoms(symbols='NH3', pbc=False)
# {'spin': 0, 'subset': 'AHB21', 'subsetind': 0, 'species': '1B', 'count': -1, 'charge': 0, 'refweight': 2.53, 'refen': -17.79, 'energy': -17.79}
# ['N', 'H', 'H', 'H']
# [[-1.07147 -0.00913  1.50279]
#  [-0.61757 -0.91698  1.47415]
#  [-0.6009   0.48688  2.25356]
#  [-0.76307  0.48318  0.60817]]
# ====================
# 3 Atoms(symbols='Li2', pbc=False)
# {'spin': 0, 'subset': 'ALK8', 'subsetind': 0, 'species': 'li2', 'count': 1, 'charge': 0, 'refweight': 0.91, 'refen': 34.51, 'energy': 34.51}
# ['Li', 'Li']
# [[ 0.       0.       1.39472]
#  [ 0.       0.      -1.39472]]
# ====================
# 4 Atoms(symbols='CLiH3Li2', pbc=False)
# {'spin': 0, 'subset': 'ALK8', 'subsetind': 0, 'species': 'li3_me', 'count': -1, 'charge': 0, 'refweight': 0.91, 'refen': 34.51, 'energy': 34.51}
# ['C', 'Li', 'H', 'H', 'H', 'Li', 'Li']
# [[ 0.02215  0.93221  0.     ]
#  [-0.08463 -3.61313  0.     ]
#  [-0.94088  1.46591  0.     ]
#  [ 0.53399  1.36184 -0.87369]
#  [ 0.53399  1.36184  0.87369]
#  [ 1.16375 -0.78056  0.     ]
#  [-1.22836 -0.7281   0.     ]]
# ====================
# 5 Atoms(symbols='CLiH3', pbc=False)
# {'spin': 0, 'subset': 'ALK8', 'subsetind': 0, 'species': 'li_me', 'count': 1, 'charge': 0, 'refweight': 0.91, 'refen': 34.51, 'energy': 34.51}
# ['C', 'Li', 'H', 'H', 'H']
# [[-0.       0.      -0.13553]
#  [ 0.       0.       1.83894]
#  [-0.50351  0.87211 -0.56787]
#  [-0.50351 -0.87211 -0.56787]
#  [ 1.00702  0.      -0.56787]]
# ====================
# 6 Atoms(symbols='F', pbc=False)
# {'spin': 1, 'subset': 'ALKBDE10', 'subsetind': 0, 'species': 'f', 'count': 1, 'charge': 0, 'refweight': 0.56, 'refen': 117.5, 'energy': 117.5}
# ['F']
# [[0. 0. 0.]]
# ====================
# 7 Atoms(symbols='K', pbc=False)
# {'spin': 1, 'subset': 'ALKBDE10', 'subsetind': 0, 'species': 'k', 'count': 1, 'charge': 0, 'refweight': 0.56, 'refen': 117.5, 'energy': 117.5}
# ['K']
# [[0. 0. 0.]]
# ====================
# 8 Atoms(symbols='KF', pbc=False)
# {'spin': 0, 'subset': 'ALKBDE10', 'subsetind': 0, 'species': 'kf', 'count': -1, 'charge': 0, 'refweight': 0.56, 'refen': 117.5, 'energy': 117.5}
# ['K', 'F']
# [[ 0.       0.      -1.08887]
#  [ 0.       0.       1.08887]]
# ====================
# 9 Atoms(symbols='NHCHC2H2CO3NCH4C2OH4', pbc=False)
# {'spin': 0, 'subset': 'Amino20x4', 'subsetind': 0, 'species': 'ASP_xad', 'count': 1, 'charge': 0, 'refweight': 23.31, 'refen': 0.157, 'energy': 0.157}
# ['N', 'H', 'C', 'H', 'C', 'C', 'H', 'H', 'C', 'O', 'O', 'O', 'N', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'O', 'H', 'H', 'H', 'H']
# [[-1.76021  0.57735  0.09223]
#  [-1.99806  1.49143 -0.26385]
#  [-0.35267  0.27998  0.13526]
#  [-0.08563 -0.08812  1.12682]
#  [-0.00914 -0.80686 -0.88781]
#  [ 0.37214  1.59585 -0.15847]
#  [-0.03106 -0.41354 -1.90487]
#  [-0.77339 -1.58202 -0.82132]
#  [ 1.30764 -1.48435 -0.64968]
#  [-0.23023  2.55143 -0.64561]
#  [ 1.53734 -2.44114 -1.5675 ]
#  [ 2.08907 -1.24958  0.25122]
#  [ 1.68357  1.59409  0.14377]
#  [ 2.54149  2.72612 -0.13332]
#  [ 2.07297  0.72924  0.49165]
#  [ 1.91979  3.52235 -0.52949]
#  [ 3.02813  3.07046  0.77666]
#  [ 3.30327  2.46809 -0.86698]
#  [-2.6785  -0.28994  0.5832 ]
#  [-4.11087  0.18025  0.53377]
#  [-2.35961 -1.38487  1.03969]
#  [-4.47826  0.27369  1.55337]
#  [-4.70909 -0.57842  0.03592]
#  [-4.2294   1.13168  0.02171]
#  [ 2.38761 -2.84041 -1.3281 ]]
# ====================
# 10 Atoms(symbols='NHCHC2H2CO3NCH4C2OH4', pbc=False)
# {'spin': 0, 'subset': 'Amino20x4', 'subsetind': 0, 'species': 'ASP_xaz', 'count': -1, 'charge': 0, 'refweight': 23.31, 'refen': 0.157, 'energy': 0.157}
# ['N', 'H', 'C', 'H', 'C', 'C', 'H', 'H', 'C', 'O', 'O', 'O', 'N', 'C', 'H', 'H', 'H', 'H', 'C', 'C', 'O', 'H', 'H', 'H', 'H']
# [[-1.14806e+00 -1.12267e+00  7.09400e-02]
#  [-9.60920e-01 -2.11271e+00  1.52300e-01]
#  [ 7.80000e-04 -2.77520e-01 -1.07620e-01]
#  [-6.21600e-02  1.80480e-01 -1.09960e+00]
#  [ 7.37500e-02  8.47410e-01  9.53130e-01]
#  [ 1.24624e+00 -1.16027e+00 -9.64800e-02]
#  [ 8.66280e-01  6.60390e-01  1.67159e+00]
#  [-8.78160e-01  9.03720e-01  1.47320e+00]
#  [ 3.51220e-01  2.13804e+00  2.22400e-01]
#  [ 1.15559e+00 -2.38383e+00 -4.26300e-02]
#  [-7.04830e-01  2.65853e+00 -4.09190e-01]
#  [ 1.46130e+00  2.62159e+00  1.35320e-01]
#  [ 2.40076e+00 -4.69100e-01 -1.66100e-01]
#  [ 3.69251e+00 -1.12530e+00 -1.80870e-01]
#  [ 2.36245e+00  5.42070e-01 -1.57290e-01]
#  [ 3.51806e+00 -2.19595e+00 -2.02270e-01]
#  [ 4.25768e+00 -8.34390e-01 -1.06329e+00]
#  [ 4.26646e+00 -8.73830e-01  7.08710e-01]
#  [-2.38213e+00 -6.11980e-01 -9.74100e-02]
#  [-3.53218e+00 -1.57396e+00  3.75000e-03]
#  [-2.56265e+00  5.93750e-01 -3.18210e-01]
#  [-4.04364e+00 -1.60186e+00 -9.55840e-01]
#  [-4.23644e+00 -1.19963e+00  7.42170e-01]
#  [-3.21752e+00 -2.57794e+00  2.74560e-01]
#  [-1.45388e+00  2.02263e+00 -3.40680e-01]]
# ====================
# 11 Atoms(symbols='NHCHC2H2CONCHCNH2C2OH3NCH4', pbc=False)
# {'spin': 0, 'subset': 'Amino20x4', 'subsetind': 1, 'species': 'HIS_xaq', 'count': -1, 'charge': 0, 'refweight': 23.31, 'refen': 7.318, 'energy': 7.318}
# ['N', 'H', 'C', 'H', 'C', 'C', 'H', 'H', 'C', 'O', 'N', 'C', 'H', 'C', 'N', 'H', 'H', 'C', 'C', 'O', 'H', 'H', 'H', 'N', 'C', 'H', 'H', 'H', 'H']
# [[-1.84130e-01  1.11299e+00  8.33200e-02]
#  [-1.05391e+00  7.66530e-01 -2.98390e-01]
#  [ 4.80940e-01  2.64450e-01  1.05564e+00]
#  [ 9.08870e-01  9.20120e-01  1.81727e+00]
#  [-5.56350e-01 -6.65570e-01  1.69267e+00]
#  [ 1.64434e+00 -5.19400e-01  4.24680e-01]
#  [-1.18456e+00 -7.27700e-02  2.35719e+00]
#  [-3.09900e-02 -1.40490e+00  2.29603e+00]
#  [-1.43896e+00 -1.31953e+00  6.88880e-01]
#  [ 1.65015e+00 -1.75221e+00  3.41950e-01]
#  [-1.00120e+00 -2.27550e+00 -1.89190e-01]
#  [-2.76542e+00 -1.11498e+00  3.49050e-01]
#  [-2.99500e-02 -2.56663e+00 -2.23170e-01]
#  [-2.04169e+00 -2.60370e+00 -9.98210e-01]
#  [-3.13638e+00 -1.91906e+00 -6.98380e-01]
#  [-3.46579e+00 -4.50390e-01  8.28180e-01]
#  [-1.95688e+00 -3.33830e+00 -1.78029e+00]
#  [ 2.70620e-01  2.33882e+00 -2.61470e-01]
#  [-6.25640e-01  3.13594e+00 -1.17200e+00]
#  [ 1.34500e+00  2.78387e+00  1.51130e-01]
#  [-1.45242e+00  2.55352e+00 -1.57044e+00]
#  [-2.90200e-02  3.53291e+00 -1.98862e+00]
#  [-1.02246e+00  3.97961e+00 -6.10720e-01]
#  [ 2.64359e+00  2.70330e-01  2.03000e-03]
#  [ 3.81764e+00 -2.53810e-01 -6.62420e-01]
#  [ 2.50099e+00  1.27292e+00  9.37100e-02]
#  [ 3.82303e+00  1.28400e-02 -1.71821e+00]
#  [ 4.71927e+00  1.35270e-01 -1.95370e-01]
#  [ 3.80084e+00 -1.33478e+00 -5.68920e-01]]
# ====================
# 12 Atoms(symbols='NHCHC2H2CONCHCNH2C2OH3NCH4', pbc=False)
# {'spin': 0, 'subset': 'Amino20x4', 'subsetind': 1, 'species': 'HIS_xau', 'count': 1, 'charge': 0, 'refweight': 23.31, 'refen': 7.318, 'energy': 7.318}
# ['N', 'H', 'C', 'H', 'C', 'C', 'H', 'H', 'C', 'O', 'N', 'C', 'H', 'C', 'N', 'H', 'H', 'C', 'C', 'O', 'H', 'H', 'H', 'N', 'C', 'H', 'H', 'H', 'H']
# [[-1.65143  0.10512 -0.30625]
#  [-1.51333  0.36259 -1.27642]
#  [-0.73395  0.75904  0.59832]
#  [-1.29239  1.41997  1.26645]
#  [ 0.03487 -0.26795  1.45075]
#  [ 0.21905  1.57323 -0.27519]
#  [ 0.5444   0.23428  2.27478]
#  [-0.70736 -0.92763  1.90142]
#  [ 1.05009 -1.00799  0.65858]
#  [ 0.12804  1.57008 -1.49985]
#  [ 0.73724 -1.7949  -0.42163]
#  [ 2.42863 -1.05978  0.73019]
#  [-0.19325 -1.92753 -0.78218]
#  [ 1.90026 -2.2709  -0.94539]
#  [ 2.95121 -1.8464  -0.26365]
#  [ 3.05933 -0.57794  1.45899]
#  [ 1.92512 -2.91218 -1.80931]
#  [-2.87713 -0.30126  0.14119]
#  [-3.84277 -0.74136 -0.93147]
#  [-3.15891 -0.32302  1.33252]
#  [-4.67932 -0.04574 -0.94768]
#  [-4.23494 -1.72032 -0.66872]
#  [-3.39201 -0.78022 -1.91991]
#  [ 1.15075  2.28516  0.39206]
#  [ 2.2342   2.92959 -0.32627]
#  [ 1.2548   2.12283  1.37787]
#  [ 2.71888  3.64478  0.33112]
#  [ 2.96512  2.20116 -0.67681]
#  [ 1.8253   3.45002 -1.18638]]
# ====================
# 13 Atoms(symbols='NC2OC7OH9NHCH3COCH3', pbc=False)
# {'spin': 0, 'subset': 'Amino20x4', 'subsetind': 2, 'species': 'TYR_xag', 'count': -1, 'charge': 0, 'refweight': 23.31, 'refen': 1.772, 'energy': 1.772}
# ['N', 'C', 'C', 'O', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'O', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'N', 'H', 'C', 'H', 'H', 'H', 'C', 'O', 'C', 'H', 'H', 'H']
# [[ 2.76821 -0.14759  0.13017]
#  [ 1.36218  0.01288 -0.12177]
#  [ 1.07141  1.50548 -0.138  ]
#  [ 1.78189  2.29786  0.47691]
#  [ 0.51506 -0.68325  0.96756]
#  [-0.94809 -0.62987  0.64897]
#  [-1.47062 -1.4183  -0.38079]
#  [-1.80797  0.26142  1.2982 ]
#  [-2.80802 -1.31413 -0.75717]
#  [-3.14607  0.37086  0.93547]
#  [-3.64927 -0.41632 -0.09976]
#  [-4.96889 -0.26677 -0.41924]
#  [ 3.24557  0.65199  0.51727]
#  [ 1.12104 -0.44279 -1.08349]
#  [ 0.86455 -1.71454  1.01707]
#  [ 0.72389 -0.19917  1.9229 ]
#  [-0.82485 -2.12435 -0.88987]
#  [-1.42203  0.88182  2.09801]
#  [-3.19893 -1.93626 -1.55382]
#  [-3.81134  1.05509  1.4434 ]
#  [-5.18008 -0.88631 -1.12549]
#  [-0.01859  1.86657 -0.85177]
#  [-0.6167   1.12463 -1.17862]
#  [-0.56083  3.20728 -0.77127]
#  [ 0.25845  3.8893  -0.56895]
#  [-1.028    3.47071 -1.71604]
#  [-1.29681  3.29337  0.02901]
#  [ 3.39942 -1.31411 -0.15232]
#  [ 2.80596 -2.27737 -0.62967]
#  [ 4.87558 -1.34804  0.15846]
#  [ 5.05861 -2.13864  0.8824 ]
#  [ 5.25204 -0.40658  0.55015]
#  [ 5.41406 -1.60264 -0.75109]]
# ====================
# 14 Atoms(symbols='NC2OC7OH9NHCH3COCH3', pbc=False)
# {'spin': 0, 'subset': 'Amino20x4', 'subsetind': 2, 'species': 'TYR_xan', 'count': 1, 'charge': 0, 'refweight': 23.31, 'refen': 1.772, 'energy': 1.772}
# ['N', 'C', 'C', 'O', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'O', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'N', 'H', 'C', 'H', 'H', 'H', 'C', 'O', 'C', 'H', 'H', 'H']
# [[ 0.92691  0.61243  1.03892]
#  [ 1.14722 -0.73864  0.53123]
#  [ 2.61528 -1.12131  0.32368]
#  [ 3.04021 -2.17969  0.77879]
#  [ 0.32602 -1.03487 -0.73733]
#  [-1.12309 -0.71134 -0.52519]
#  [-1.67576  0.47374 -1.02108]
#  [-1.94181 -1.55542  0.22881]
#  [-3.00277  0.81051 -0.7731 ]
#  [-3.27112 -1.22918  0.48407]
#  [-3.80418 -0.04084 -0.01478]
#  [-5.1      0.3377   0.20047]
#  [ 0.49029  0.6795   1.94196]
#  [ 0.80343 -1.40647  1.31849]
#  [ 0.72326 -0.46073 -1.57162]
#  [ 0.46252 -2.09474 -0.95955]
#  [-1.05805  1.13661 -1.61443]
#  [-1.54164 -2.4857   0.61498]
#  [-3.43296  1.72187 -1.16486]
#  [-3.89441 -1.90006  1.06376]
#  [-5.53185 -0.35225  0.71475]
#  [ 3.33463 -0.25377 -0.4176 ]
#  [ 2.85489  0.56994 -0.76543]
#  [ 4.72318 -0.49764 -0.73921]
#  [ 4.96784 -1.50333 -0.41161]
#  [ 4.88505 -0.41833 -1.81227]
#  [ 5.37839  0.20913 -0.23149]
#  [ 0.97896  1.75221  0.3103 ]
#  [ 1.44918  1.80195 -0.82875]
#  [ 0.38936  2.9675   0.97869]
#  [ 0.43571  2.91127  2.06397]
#  [-0.65597  3.0464   0.68008]
#  [ 0.91565  3.85104  0.63244]]
# ====================
# 15 Atoms(symbols='H2', pbc=False)
# {'spin': 0, 'subset': 'BH76', 'subsetind': 0, 'species': 'H2', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 1.6, 'energy': 1.6}
# ['H', 'H']
# [[ 0.       0.       0.37094]
#  [ 0.       0.      -0.37094]]
# ====================
# 16 Atoms(symbols='HFH', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 0, 'species': 'RKT10', 'count': 1, 'charge': 0, 'refweight': 3.05, 'refen': 1.6, 'energy': 1.6}
# ['H', 'F', 'H']
# [[ 0.14657 -0.24726  0.     ]
#  [ 0.       1.21155  0.     ]
#  [-0.14657 -0.96428  0.     ]]
# ====================
# 17 Atoms(symbols='F', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 0, 'species': 'f', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 1.6, 'energy': 1.6}
# ['F']
# [[0. 0. 0.]]
# ====================
# 18 Atoms(symbols='CH4O', pbc=False)
# {'spin': 2, 'subset': 'BH76', 'subsetind': 1, 'species': 'RKT11', 'count': 1, 'charge': 0, 'refweight': 3.05, 'refen': 8.9, 'energy': 8.9}
# ['C', 'H', 'H', 'H', 'H', 'O']
# [[ 8.70000e-04 -5.05610e-01  0.00000e+00]
#  [-1.05538e+00 -7.48060e-01  0.00000e+00]
#  [ 5.20750e-01 -7.70710e-01  9.12450e-01]
#  [ 5.20750e-01 -7.70710e-01 -9.12450e-01]
#  [ 1.21400e-02  7.96780e-01  0.00000e+00]
#  [ 8.70000e-04  1.99832e+00  0.00000e+00]]
# ====================
# 19 Atoms(symbols='CH3', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 1, 'species': 'ch3', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 8.9, 'energy': 8.9}
# ['C', 'H', 'H', 'H']
# [[ 0.       0.       0.     ]
#  [ 0.53866  0.93298  0.     ]
#  [ 0.53866 -0.93298  0.     ]
#  [-1.07732  0.       0.     ]]
# ====================
# 20 Atoms(symbols='OH', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 1, 'species': 'oh', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 8.9, 'energy': 8.9}
# ['O', 'H']
# [[ 0.       0.       0.48445]
#  [ 0.       0.      -0.48445]]
# ====================
# 21 Atoms(symbols='PH3', pbc=False)
# {'spin': 0, 'subset': 'BH76', 'subsetind': 2, 'species': 'PH3', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 2.9, 'energy': 2.9}
# ['P', 'H', 'H', 'H']
# [[ 0.       0.       0.56885]
#  [ 0.59567  1.03173 -0.18962]
#  [ 0.59567 -1.03173 -0.18962]
#  [-1.19134  0.      -0.18962]]
# ====================
# 22 Atoms(symbols='PH4', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 2, 'species': 'RKT12', 'count': 1, 'charge': 0, 'refweight': 3.05, 'refen': 2.9, 'energy': 2.9}
# ['P', 'H', 'H', 'H', 'H']
# [[ 8.26230e-01  3.30000e-04 -4.22750e-01]
#  [ 8.55410e-01  1.03491e+00  5.40670e-01]
#  [ 8.71460e-01 -1.02481e+00  5.50120e-01]
#  [-6.57620e-01 -1.07100e-02 -4.62120e-01]
#  [-1.89549e+00  2.70000e-04 -2.05920e-01]]
# ====================
# 23 Atoms(symbols='H', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 2, 'species': 'h', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 2.9, 'energy': 2.9}
# ['H']
# [[0. 0. 0.]]
# ====================
# 24 Atoms(symbols='C2H5', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 3, 'species': 'C2H5', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 17.8, 'energy': 17.8}
# ['C', 'C', 'H', 'H', 'H', 'H', 'H']
# [[-0.02568 -0.62491  0.     ]
#  [-0.02568  0.86613  0.     ]
#  [ 0.99398 -1.02874  0.     ]
#  [-0.52373 -1.02453  0.88342]
#  [-0.52373 -1.02453 -0.88342]
#  [ 0.05242  1.41829 -0.92432]
#  [ 0.05242  1.41829  0.92432]]
# ====================
# 25 Atoms(symbols='NH3', pbc=False)
# {'spin': 0, 'subset': 'BH76', 'subsetind': 3, 'species': 'NH3', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 17.8, 'energy': 17.8}
# ['N', 'H', 'H', 'H']
# [[ 0.       0.       0.28223]
#  [ 0.46901  0.81235 -0.09408]
#  [ 0.46901 -0.81235 -0.09408]
#  [-0.93802  0.      -0.09408]]
# ====================
# 26 Atoms(symbols='C2NH8', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 3, 'species': 'RKT20', 'count': 1, 'charge': 0, 'refweight': 3.05, 'refen': 17.8, 'energy': 17.8}
# ['C', 'C', 'N', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[-1.37322e+00 -5.18440e-01 -5.00000e-05]
#  [-3.92560e-01  6.31460e-01  0.00000e+00]
#  [ 1.97764e+00 -4.10450e-01 -8.00000e-05]
#  [-1.24171e+00 -1.14679e+00 -8.80530e-01]
#  [-1.24168e+00 -1.14689e+00  8.80360e-01]
#  [-2.40455e+00 -1.56450e-01 -0.00000e+00]
#  [-4.09750e-01  1.24584e+00 -8.97250e-01]
#  [-4.09730e-01  1.24575e+00  8.97310e-01]
#  [ 7.77530e-01  7.76800e-02 -6.00000e-05]
#  [ 2.35912e+00  8.94400e-02 -8.04830e-01]
#  [ 2.35892e+00  8.88500e-02  8.05130e-01]]
# ====================
# 27 Atoms(symbols='CH4', pbc=False)
# {'spin': 0, 'subset': 'BH76', 'subsetind': 4, 'species': 'CH4', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 13.9, 'energy': 13.9}
# ['C', 'H', 'H', 'H', 'H']
# [[ 0.       0.       0.     ]
#  [ 0.62784 -0.62784  0.62784]
#  [-0.62784  0.62784  0.62784]
#  [-0.62784 -0.62784 -0.62784]
#  [ 0.62784  0.62784 -0.62784]]
# ====================
# 28 Atoms(symbols='NH2', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 4, 'species': 'NH2', 'count': -1, 'charge': 0, 'refweight': 3.05, 'refen': 13.9, 'energy': 13.9}
# ['N', 'H', 'H']
# [[ 0.       0.       0.42425]
#  [-0.80231  0.      -0.21212]
#  [ 0.80231  0.      -0.21212]]
# ====================
# 29 Atoms(symbols='CNH6', pbc=False)
# {'spin': 1, 'subset': 'BH76', 'subsetind': 4, 'species': 'RKT21', 'count': 1, 'charge': 0, 'refweight': 3.05, 'refen': 13.9, 'energy': 13.9}
# ['C', 'N', 'H', 'H', 'H', 'H', 'H', 'H']
# [[-1.06378e+00 -1.00000e-05 -8.26100e-02]
#  [ 1.51023e+00 -1.00000e-05 -2.31690e-01]
#  [-1.38701e+00  9.08530e-01 -5.79650e-01]
#  [-1.26670e+00 -4.58000e-03  9.82400e-01]
#  [-1.38778e+00 -9.03890e-01 -5.87600e-01]
#  [ 2.40080e-01 -7.00000e-05 -2.46600e-01]
#  [ 1.67743e+00  8.05570e-01  3.72850e-01]
#  [ 1.67753e+00 -8.05530e-01  3.72900e-01]]
# ====================
# 30 Atoms(symbols='H', pbc=False)
# {'spin': 1, 'subset': 'BH76RC', 'subsetind': 0, 'species': 'h', 'count': -1, 'charge': 0, 'refweight': 2.66, 'refen': 42.1, 'energy': 42.1}
# ['H']
# [[0. 0. 0.]]
# ====================
# 31 Atoms(symbols='FH', pbc=False)
# {'spin': 0, 'subset': 'BH76RC', 'subsetind': 0, 'species': 'hf', 'count': -1, 'charge': 0, 'refweight': 2.66, 'refen': 42.1, 'energy': 42.1}
# ['F', 'H']
# [[ 0.       0.       0.45769]
#  [ 0.       0.      -0.45769]]
# ====================
# 32 Atoms(symbols='HFH', pbc=False)
# {'spin': 1, 'subset': 'BH76RC', 'subsetind': 0, 'species': 'hfhts', 'count': 1, 'charge': 0, 'refweight': 2.66, 'refen': 42.1, 'energy': 42.1}
# ['H', 'F', 'H']
# [[ 0.       0.       1.13722]
#  [ 0.       0.       0.     ]
#  [ 0.       0.      -1.13722]]
# ====================
# 33 Atoms(symbols='SN2CH3C2H5', pbc=False)
# {'spin': 0, 'subset': 'BHROT27', 'subsetind': 0, 'species': 'ethylthiourea_180', 'count': -1, 'charge': 0, 'refweight': 9.06, 'refen': 10.36, 'energy': 10.36}
# ['S', 'N', 'N', 'C', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'H', 'H', 'H']
# [[-1.07651e+00  1.55909e+00 -1.64730e-01]
#  [ 1.55759e+00  1.52879e+00 -1.67000e-03]
#  [ 5.50240e-01 -5.16650e-01  7.58400e-02]
#  [ 3.94810e-01  8.15430e-01 -1.22600e-02]
#  [ 2.35939e+00  1.14610e+00  4.67020e-01]
#  [ 1.43099e+00  2.51920e+00  8.32500e-02]
#  [ 1.47821e+00 -8.90640e-01 -1.02400e-02]
#  [-5.43500e-01 -1.45978e+00 -2.53800e-02]
#  [-8.43000e-03 -2.87304e+00  7.83000e-03]
#  [-1.23656e+00 -1.28244e+00  7.93760e-01]
#  [-1.09795e+00 -1.27089e+00 -9.43000e-01]
#  [ 4.98650e-01 -3.08552e+00  9.46990e-01]
#  [-8.21630e-01 -3.58325e+00 -1.04460e-01]
#  [ 6.94470e-01 -3.04923e+00 -8.03940e-01]]
# ====================
# 34 Atoms(symbols='SN2CH3C2H5', pbc=False)
# {'spin': 0, 'subset': 'BHROT27', 'subsetind': 0, 'species': 'ethylthiourea_TS1', 'count': 1, 'charge': 0, 'refweight': 9.06, 'refen': 10.36, 'energy': 10.36}
# ['S', 'N', 'N', 'C', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'H', 'H', 'H']
# [[ 0.9878   1.69086 -0.05066]
#  [-1.61021  1.29842 -0.15111]
#  [-0.45938 -0.56434  0.46248]
#  [-0.39188  0.81146  0.08312]
#  [-2.39945  0.68604 -0.07469]
#  [-1.71733  2.24968 -0.44738]
#  [-0.09355 -0.62431  1.40485]
#  [ 0.35853 -1.43528 -0.38652]
#  [ 0.17576 -2.87823  0.0179 ]
#  [ 0.02639 -1.29125 -1.4124 ]
#  [ 1.41001 -1.14571 -0.34148]
#  [-0.86057 -3.18391 -0.09862]
#  [ 0.79399 -3.52648 -0.59574]
#  [ 0.46967 -3.03395  1.05529]]
# ====================
# 35 Atoms(symbols='C2H6', pbc=False)
# {'spin': 0, 'subset': 'BSR36', 'subsetind': 0, 'species': 'c2h6', 'count': 11, 'charge': 0, 'refweight': 3.51, 'refen': 22.86, 'energy': 22.86}
# ['C', 'C', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 0.       0.      -0.76169]
#  [ 0.       0.       0.76169]
#  [-0.8786   0.50726 -1.15577]
#  [ 0.      -1.01452 -1.15577]
#  [ 0.8786   0.50726 -1.15577]
#  [-0.8786  -0.50726  1.15577]
#  [ 0.       1.01452  1.15577]
#  [ 0.8786  -0.50726  1.15577]]
# ====================
# 36 Atoms(symbols='CH4', pbc=False)
# {'spin': 0, 'subset': 'BSR36', 'subsetind': 0, 'species': 'ch4', 'count': -12, 'charge': 0, 'refweight': 3.51, 'refen': 22.86, 'energy': 22.86}
# ['C', 'H', 'H', 'H', 'H']
# [[ 0.       0.       0.     ]
#  [ 0.62664 -0.62664  0.62664]
#  [-0.62664  0.62664  0.62664]
#  [-0.62664 -0.62664 -0.62664]
#  [ 0.62664  0.62664 -0.62664]]
# ====================
# 37 Atoms(symbols='C10H18', pbc=False)
# {'spin': 0, 'subset': 'BSR36', 'subsetind': 0, 'species': 'r14', 'count': -1, 'charge': 0, 'refweight': 3.51, 'refen': 22.86, 'energy': 22.86}
# ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 0.22851  0.7334  -0.72045]
#  [-0.22851 -0.7334  -0.72045]
#  [-1.75579 -0.82243 -0.7175 ]
#  [ 0.40656 -1.51671  0.42956]
#  [ 1.75579  0.82243 -0.7175 ]
#  [-0.40656  1.51671  0.42956]
#  [-2.38592 -0.02947  0.42515]
#  [ 1.92929 -1.42561  0.38563]
#  [ 2.38592  0.02947  0.42515]
#  [-1.92929  1.42561  0.38563]
#  [-0.13588  1.1881  -1.64938]
#  [ 0.13588 -1.1881  -1.64938]
#  [-2.06314 -1.86998 -0.67013]
#  [-2.13307 -0.42412 -1.66435]
#  [ 0.05434 -1.1363   1.39109]
#  [ 0.08534 -2.55961  0.37146]
#  [ 2.06314  1.86998 -0.67013]
#  [ 2.13307  0.42412 -1.66435]
#  [-0.05434  1.1363   1.39109]
#  [-0.08534  2.55961  0.37146]
#  [-2.10756 -0.46996  1.38545]
#  [-3.47357 -0.08779  0.35995]
#  [ 2.36822 -1.98643  1.21237]
#  [ 2.28857 -1.88786 -0.53884]
#  [ 2.10756  0.46996  1.38545]
#  [ 3.47357  0.08779  0.35995]
#  [-2.36822  1.98643  1.21237]
#  [-2.28857  1.88786 -0.53884]]
# ====================
# 38 Atoms(symbols='CHOCH2CH4CH2OH', pbc=False)
# {'spin': 0, 'subset': 'BUT14DIOL', 'subsetind': 0, 'species': 'B1', 'count': -1, 'charge': 0, 'refweight': 20.3, 'refen': 1.31, 'energy': 1.31}
# ['C', 'H', 'O', 'C', 'H', 'H', 'C', 'H', 'H', 'H', 'H', 'C', 'H', 'H', 'O', 'H']
# [[ 1.57838  0.14769  0.34381]
#  [ 1.39475  0.01297  1.41355]
#  [ 1.35993 -1.0862  -0.35978]
#  [ 0.65385  1.2151  -0.22132]
#  [ 1.05783  2.18028  0.09392]
#  [ 0.72969  1.18486 -1.31144]
#  [-0.81733  1.15213  0.20816]
#  [-1.30353  2.06574 -0.14583]
#  [-0.88377  1.15976  1.29926]
#  [ 1.98412 -1.73445 -0.02139]
#  [ 2.61629  0.45895  0.20654]
#  [-1.62773 -0.03405 -0.3113 ]
#  [-2.68423  0.15102 -0.11857]
#  [-1.50187 -0.11815 -1.39751]
#  [-1.32426 -1.26015  0.33338]
#  [-0.41765 -1.47531  0.07664]]
# ====================
# 39 Atoms(symbols='CHOCH2CH4CH2OH', pbc=False)
# {'spin': 0, 'subset': 'BUT14DIOL', 'subsetind': 0, 'species': 'B4', 'count': 1, 'charge': 0, 'refweight': 20.3, 'refen': 1.31, 'energy': 1.31}
# ['C', 'H', 'O', 'C', 'H', 'H', 'C', 'H', 'H', 'H', 'H', 'C', 'H', 'H', 'O', 'H']
# [[-1.43893 -0.10981  0.53207]
#  [-2.47234  0.07457  0.82488]
#  [-1.47253 -1.08355 -0.50245]
#  [-0.79822  1.20409  0.08704]
#  [-1.45704  1.69415 -0.63221]
#  [-0.73096  1.86121  0.9599 ]
#  [ 0.59163  1.05614 -0.5438 ]
#  [ 1.01261  2.05247 -0.69992]
#  [ 0.50353  0.59623 -1.53048]
#  [-0.5861  -1.46237 -0.50394]
#  [-0.91678 -0.50572  1.40801]
#  [ 1.58071  0.23808  0.28169]
#  [ 2.60614  0.47205 -0.01114]
#  [ 1.48113  0.46927  1.34252]
#  [ 1.36072 -1.17961  0.16619]
#  [ 1.84313 -1.47756 -0.60953]]
# ====================
# 40 Atoms(symbols='C60', pbc=False)
# {'spin': 0, 'subset': 'C60ISO', 'subsetind': 0, 'species': 1, 'count': -1, 'charge': 0, 'refweight': 0.58, 'refen': 56.89, 'energy': 56.89}
# ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C']
# [[-1.23626  0.       3.32998]
#  [-0.38203 -1.17576  3.32998]
#  [ 1.00016 -0.72666  3.32998]
#  [ 1.00016  0.72666  3.32998]
#  [-0.38203  1.17576  3.32998]
#  [ 2.34434 -2.60146  0.59464]
#  [ 3.19857 -1.4257   0.59464]
#  [ 2.96247 -0.69904  1.83091]
#  [ 1.96231 -1.4257   2.59496]
#  [ 1.58028 -2.60146  1.83091]
#  [ 3.19857  1.4257   0.59464]
#  [ 2.34434  2.60146  0.59464]
#  [ 1.58028  2.60146  1.83091]
#  [ 1.96231  1.4257   2.59496]
#  [ 2.96247  0.69904  1.83091]
#  [-0.36751  3.48259  0.59464]
#  [-1.74969  3.03349  0.59464]
#  [-1.9858   2.30683  1.83091]
#  [-0.74954  2.30683  2.59496]
#  [ 0.25062  3.03349  1.83091]
#  [-3.42571  0.72666  0.59464]
#  [-3.42571 -0.72666  0.59464]
#  [-2.80757 -1.17576  1.83091]
#  [-2.42555  0.       2.59496]
#  [-2.80757  1.17576  1.83091]
#  [-1.74969 -3.03349  0.59464]
#  [-0.36751 -3.48259  0.59464]
#  [ 0.25062 -3.03349  1.83091]
#  [-0.74954 -2.30683  2.59496]
#  [-1.9858  -2.30683  1.83091]
#  [-0.25062 -3.03349 -1.83091]
#  [ 0.74954 -2.30683 -2.59496]
#  [ 1.9858  -2.30683 -1.83091]
#  [ 1.74969 -3.03349 -0.59464]
#  [ 0.36751 -3.48259 -0.59464]
#  [ 2.80757 -1.17576 -1.83091]
#  [ 2.42555  0.      -2.59496]
#  [ 2.80757  1.17576 -1.83091]
#  [ 3.42571  0.72666 -0.59464]
#  [ 3.42571 -0.72666 -0.59464]
#  [ 1.9858   2.30683 -1.83091]
#  [ 0.74954  2.30683 -2.59496]
#  [-0.25062  3.03349 -1.83091]
#  [ 0.36751  3.48259 -0.59464]
#  [ 1.74969  3.03349 -0.59464]
#  [-1.58028  2.60146 -1.83091]
#  [-1.96231  1.4257  -2.59496]
#  [-2.96247  0.69904 -1.83091]
#  [-3.19857  1.4257  -0.59464]
#  [-2.34434  2.60146 -0.59464]
#  [-2.96247 -0.69904 -1.83091]
#  [-1.96231 -1.4257  -2.59496]
#  [-1.58028 -2.60146 -1.83091]
#  [-2.34434 -2.60146 -0.59464]
#  [-3.19857 -1.4257  -0.59464]
#  [-1.00016 -0.72666 -3.32998]
#  [-1.00016  0.72666 -3.32998]
#  [ 0.38203  1.17576 -3.32998]
#  [ 1.23626  0.      -3.32998]
#  [ 0.38203 -1.17576 -3.32998]]
# ====================
# 41 Atoms(symbols='C60', pbc=False)
# {'spin': 0, 'subset': 'C60ISO', 'subsetind': 0, 'species': 4, 'count': 1, 'charge': 0, 'refweight': 0.58, 'refen': 56.89, 'energy': 56.89}
# ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C']
# [[ 3.69552  0.58349  0.44256]
#  [ 3.13431  1.68452 -0.24557]
#  [ 2.93823  1.25581 -1.63391]
#  [ 3.69552 -0.58349 -0.44256]
#  [ 3.24798 -0.17713 -1.71744]
#  [ 3.13431 -1.68452  0.24557]
#  [ 3.24798  0.17713  1.71744]
#  [ 2.93823 -1.25581  1.63391]
#  [ 2.39244  1.04066  2.41627]
#  [ 2.16994  2.52988  0.40621]
#  [ 1.89677  2.23879  1.78335]
#  [ 1.10597  3.14416 -0.40621]
#  [ 1.88293  1.76302 -2.36154]
#  [ 0.99046  2.76204 -1.78335]
#  [ 1.10398  0.89542 -3.24237]
#  [ 2.39244 -1.04066 -2.41627]
#  [ 1.33676 -0.4847  -3.24956]
#  [ 2.16994 -2.52988 -0.40621]
#  [ 1.89677 -2.23879 -1.78335]
#  [ 1.10597 -3.14416  0.40621]
#  [ 1.88293 -1.76302  2.36154]
#  [ 0.99046 -2.76204  1.78335]
#  [ 1.33676  0.4847   3.24956]
#  [ 1.10398 -0.89542  3.24237]
#  [ 0.58536  2.51218  2.36154]
#  [ 0.22346  1.40378  3.24237]
#  [-0.10832  3.55665  0.24557]
#  [-0.38155  3.17249  1.63391]
#  [-1.34245  3.49216 -0.44256]
#  [-0.29498  2.59225 -2.41627]
#  [-0.24861  1.40002 -3.24956]
#  [-1.47059  2.9014  -1.71744]
#  [-1.32744  0.50837 -3.24237]
#  [ 0.22346 -1.40378 -3.24237]
#  [ 0.58536 -2.51218 -2.36154]
#  [-1.08814 -0.91531 -3.24956]
#  [-0.10832 -3.55665 -0.24557]
#  [-0.38155 -3.17249 -1.63391]
#  [-1.34245 -3.49216  0.44256]
#  [-0.29498 -2.59225  2.41627]
#  [-0.24861 -1.40002  3.24956]
#  [-1.47059 -2.9014   1.71744]
#  [-1.08814  0.91531  3.24956]
#  [-1.32744 -0.50837  3.24237]
#  [-1.77739  2.72427  1.71744]
#  [-2.35307  2.90867  0.44256]
#  [-2.09746  1.55158  2.41627]
#  [-2.55668  1.91668 -1.63391]
#  [-2.46829  0.74915 -2.36154]
#  [-3.02599  1.87213 -0.24557]
#  [-2.09746 -1.55158 -2.41627]
#  [-1.77739 -2.72427 -1.71744]
#  [-2.35307 -2.90867 -0.44256]
#  [-2.88723 -0.52325 -1.78335]
#  [-2.55668 -1.91668  1.63391]
#  [-2.46829 -0.74915  2.36154]
#  [-2.88723  0.52325  1.78335]
#  [-3.2759   0.61428  0.40621]
#  [-3.02599 -1.87213  0.24557]
#  [-3.2759  -0.61428 -0.40621]]
# ====================
# 42 Atoms(symbols='NH3SiH2', pbc=False)
# {'spin': 0, 'subset': 'CARBHB12', 'subsetind': 0, 'species': '3N', 'count': -1, 'charge': 0, 'refweight': 9.42, 'refen': 1.205, 'energy': 1.205}
# ['N', 'H', 'H', 'H', 'Si', 'H', 'H']
# [[-2.02182  0.03843 -0.13709]
#  [-1.05692  0.34213 -0.15347]
#  [-2.58897  0.87369 -0.17721]
#  [-2.17994 -0.37485  0.77106]
#  [ 1.99386  0.01385 -0.05021]
#  [ 2.87433 -0.37134 -1.20958]
#  [ 2.97945 -0.5219   0.9565 ]]
# ====================
# 43 Atoms(symbols='NH3', pbc=False)
# {'spin': 0, 'subset': 'CARBHB12', 'subsetind': 0, 'species': '3N_A', 'count': 1, 'charge': 0, 'refweight': 9.42, 'refen': 1.205, 'energy': 1.205}
# ['N', 'H', 'H', 'H']
# [[ 0.       0.      -0.28533]
#  [-0.46842  0.81133  0.09511]
#  [-0.46842 -0.81133  0.09511]
#  [ 0.93684  0.       0.09511]]
# ====================
# 44 Atoms(symbols='SiH2', pbc=False)
# {'spin': 0, 'subset': 'CARBHB12', 'subsetind': 0, 'species': '3N_B', 'count': 1, 'charge': 0, 'refweight': 9.42, 'refen': 1.205, 'energy': 1.205}
# ['Si', 'H', 'H']
# [[ 0.       0.      -0.69484]
#  [ 1.08692  0.       0.34742]
#  [-1.08692  0.       0.34742]]
# ====================
# 45 Atoms(symbols='C6H8', pbc=False)
# {'spin': 0, 'subset': 'CDIE20', 'subsetind': 0, 'species': 'P26', 'count': 1, 'charge': 0, 'refweight': 14.02, 'refen': -2.5, 'energy': -2.5}
# ['C', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[-0.26286  0.40275  0.4336 ]
#  [ 0.77683  1.33862 -0.14462]
#  [ 1.17465  0.13003  0.04405]
#  [-1.37786 -0.10239 -0.39263]
#  [ 2.18589 -0.93727 -0.0163 ]
#  [-2.57176 -0.45764  0.07171]
#  [ 0.95877  2.3439  -0.47803]
#  [-1.1731  -0.17761 -1.45759]
#  [ 2.38273 -1.33128  0.98341]
#  [ 1.82158 -1.77127 -0.61971]
#  [-2.8083  -0.39197  1.12708]
#  [-3.3512  -0.82231 -0.58255]
#  [ 3.12284 -0.57831 -0.44188]
#  [-0.50273  0.48427  1.49445]]
# ====================
# 46 Atoms(symbols='C6H8', pbc=False)
# {'spin': 0, 'subset': 'CDIE20', 'subsetind': 0, 'species': 'R26', 'count': -1, 'charge': 0, 'refweight': 14.02, 'refen': -2.5, 'energy': -2.5}
# ['C', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 0.       0.18366  0.     ]
#  [ 1.35289 -0.31156  0.     ]
#  [ 0.38421 -1.20172  0.     ]
#  [-0.89618  1.16111  0.     ]
#  [-0.05528 -2.60591  0.     ]
#  [-0.54378  2.62106  0.     ]
#  [ 2.41036 -0.1148   0.     ]
#  [-1.94692  0.89557  0.     ]
#  [-0.67687 -2.80203  0.87634]
#  [-0.67687 -2.80203 -0.87634]
#  [ 0.53803  2.76129  0.     ]
#  [-0.94351  3.13847 -0.87746]
#  [ 0.78807 -3.29478  0.     ]
#  [-0.94351  3.13847  0.87746]]
# ====================
# 47 Atoms(symbols='C7H10', pbc=False)
# {'spin': 0, 'subset': 'DARC', 'subsetind': 0, 'species': 'P3', 'count': 1, 'charge': 0, 'refweight': 1.75, 'refen': -29.9, 'energy': -29.9}
# ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[-0.3176   0.20241 -1.1199 ]
#  [ 0.51588  1.37783 -0.66639]
#  [ 0.51588  1.37783  0.66639]
#  [-0.3176   0.20241  1.1199 ]
#  [-1.36505  0.15995  0.     ]
#  [ 0.51355 -1.06494 -0.77373]
#  [ 0.51355 -1.06494  0.77373]
#  [-0.68318  0.23562 -2.14568]
#  [ 1.10241  2.01128 -1.32032]
#  [ 1.10241  2.01128  1.32032]
#  [-0.68318  0.23562  2.14568]
#  [-2.02063  1.03246  0.     ]
#  [-1.9608  -0.75758  0.     ]
#  [ 0.02524 -1.95915 -1.16905]
#  [ 1.51694 -1.02047 -1.19943]
#  [ 0.02524 -1.95915  1.16905]
#  [ 1.51694 -1.02047  1.19943]]
# ====================
# 48 Atoms(symbols='C5H6', pbc=False)
# {'spin': 0, 'subset': 'DARC', 'subsetind': 0, 'species': 'cpdiene', 'count': -1, 'charge': 0, 'refweight': 1.75, 'refen': -29.9, 'energy': -29.9}
# ['C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 0.      -1.17163  0.19064]
#  [ 0.      -0.72993 -1.07678]
#  [ 0.       0.72993 -1.07678]
#  [ 0.       1.17163  0.19064]
#  [ 0.       0.       1.11579]
#  [ 0.      -2.20239  0.51729]
#  [ 0.      -1.34551 -1.96712]
#  [ 0.       1.34551 -1.96712]
#  [ 0.       2.20239  0.51729]
#  [-0.8758   0.       1.77808]
#  [ 0.8758   0.       1.77808]]
# ====================
# 49 Atoms(symbols='C2H4', pbc=False)
# {'spin': 0, 'subset': 'DARC', 'subsetind': 0, 'species': 'ethene', 'count': -1, 'charge': 0, 'refweight': 1.75, 'refen': -29.9, 'energy': -29.9}
# ['C', 'C', 'H', 'H', 'H', 'H']
# [[ 0.66144  0.       0.     ]
#  [-0.66144  0.       0.     ]
#  [ 1.23092 -0.92311  0.     ]
#  [ 1.23092  0.92311  0.     ]
#  [-1.23092 -0.92311  0.     ]
#  [-1.23092  0.92311  0.     ]]
# ====================
# 50 Atoms(symbols='C7H8', pbc=False)
# {'spin': 0, 'subset': 'DARC', 'subsetind': 1, 'species': 'P4', 'count': 1, 'charge': 0, 'refweight': 1.75, 'refen': -33.6, 'energy': -33.6}
# ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 0.      -1.11492 -0.21254]
#  [ 1.23315 -0.66401  0.5765 ]
#  [ 1.23315  0.66401  0.5765 ]
#  [ 0.       1.11492 -0.21254]
#  [ 0.       0.      -1.28513]
#  [-1.23315 -0.66401  0.5765 ]
#  [-1.23315  0.66401  0.5765 ]
#  [ 0.      -2.14861 -0.55354]
#  [ 1.92132 -1.32975  1.07929]
#  [ 1.92132  1.32975  1.07929]
#  [ 0.       2.14861 -0.55354]
#  [-0.9003   0.      -1.90292]
#  [ 0.9003   0.      -1.90292]
#  [-1.92132 -1.32975  1.07929]
#  [-1.92132  1.32975  1.07929]]
# ====================
# 51 Atoms(symbols='C5H6', pbc=False)
# {'spin': 0, 'subset': 'DARC', 'subsetind': 1, 'species': 'cpdiene', 'count': -1, 'charge': 0, 'refweight': 1.75, 'refen': -33.6, 'energy': -33.6}
# ['C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 0.      -1.17163  0.19064]
#  [ 0.      -0.72993 -1.07678]
#  [ 0.       0.72993 -1.07678]
#  [ 0.       1.17163  0.19064]
#  [ 0.       0.       1.11579]
#  [ 0.      -2.20239  0.51729]
#  [ 0.      -1.34551 -1.96712]
#  [ 0.       1.34551 -1.96712]
#  [ 0.       2.20239  0.51729]
#  [-0.8758   0.       1.77808]
#  [ 0.8758   0.       1.77808]]
# ====================
# 52 Atoms(symbols='CHCH', pbc=False)
# {'spin': 0, 'subset': 'DARC', 'subsetind': 1, 'species': 'ethine', 'count': -1, 'charge': 0, 'refweight': 1.75, 'refen': -33.6, 'energy': -33.6}
# ['C', 'H', 'C', 'H']
# [[ 0.       0.      -0.59829]
#  [ 0.       0.      -1.66297]
#  [ 0.       0.       0.59829]
#  [ 0.       0.       1.66297]]
# ====================
# 53 Atoms(symbols='CH3CH2C3H3', pbc=False)
# {'spin': 0, 'subset': 'FH51', 'subsetind': 0, 'species': '2-pentyne', 'count': -1, 'charge': 0, 'refweight': 1.83, 'refen': -42.89, 'energy': -42.89}
# ['C', 'H', 'H', 'H', 'C', 'H', 'H', 'C', 'C', 'C', 'H', 'H', 'H']
# [[-1.15652  2.93352  1.38639]
#  [-1.859    3.64037  1.84779]
#  [-0.88476  3.31466  0.39188]
#  [-0.2501   2.90547  2.00564]
#  [-1.78583  1.53234  1.27367]
#  [-2.67209  1.57855  0.61846]
#  [-1.07752  0.85015  0.77388]
#  [-2.16997  0.9673   2.56451]
#  [-2.47847  0.52535  3.65251]
#  [-2.85195 -0.01527  4.95275]
#  [-2.42391 -1.01781  5.10694]
#  [-2.49336  0.62859  5.77044]
#  [-3.94494 -0.1011   5.05178]]
# ====================
# 54 Atoms(symbols='CH3CH2C2HCH3CN', pbc=False)
# {'spin': 0, 'subset': 'FH51', 'subsetind': 0, 'species': 'C2H5CCNCHCH3', 'count': 1, 'charge': 0, 'refweight': 1.83, 'refen': -42.89, 'energy': -42.89}
# ['C', 'H', 'H', 'H', 'C', 'H', 'H', 'C', 'C', 'H', 'C', 'H', 'H', 'H', 'C', 'N']
# [[-5.7612  -0.11225 -0.15921]
#  [-5.44177 -1.13891 -0.38608]
#  [-5.27982  0.55994 -0.8833 ]
#  [-6.84822 -0.05639 -0.30964]
#  [-5.39669  0.27714  1.28089]
#  [-5.7262   1.30497  1.49379]
#  [-5.93414 -0.38182  1.98249]
#  [-3.911    0.19356  1.57129]
#  [-3.14858  1.2596   1.89938]
#  [-3.65756  2.2273   1.95845]
#  [-1.68572  1.25171  2.19288]
#  [-1.14807  1.91751  1.49862]
#  [-1.492    1.64046  3.20564]
#  [-1.25248  0.24628  2.11705]
#  [-3.32188 -1.10903  1.47357]
#  [-2.88072 -2.18593  1.38636]]
# ====================
# 55 Atoms(symbols='CHN', pbc=False)
# {'spin': 0, 'subset': 'FH51', 'subsetind': 0, 'species': 'HCN', 'count': -1, 'charge': 0, 'refweight': 1.83, 'refen': -42.89, 'energy': -42.89}
# ['C', 'H', 'N']
# [[-1.9804   0.12195  0.     ]
#  [-3.05555  0.12195  0.     ]
#  [-0.82241  0.12195  0.     ]]
# ====================
# 56 Atoms(symbols='CH3C2H2C2H2CH3O2', pbc=False)
# {'spin': 0, 'subset': 'FH51', 'subsetind': 1, 'species': 'hexandione', 'count': -1, 'charge': 0, 'refweight': 1.83, 'refen': -6.45, 'energy': -6.45}
# ['C', 'H', 'H', 'H', 'C', 'C', 'H', 'H', 'C', 'C', 'H', 'H', 'C', 'H', 'H', 'H', 'O', 'O']
# [[-6.43818  0.02151  0.53153]
#  [-6.53999 -0.08669 -0.56004]
#  [-6.44442  1.10242  0.74135]
#  [-7.27689 -0.47678  1.02932]
#  [-5.12716 -0.57992  0.97658]
#  [-3.85937  0.16576  0.52847]
#  [-3.04772 -0.56709  0.44006]
#  [-4.02867  0.68422 -0.42369]
#  [-3.52715  1.22582  1.59281]
#  [-2.58001  0.78019  2.68898]
#  [-1.61433  0.54755  2.20369]
#  [-2.9461  -0.19633  3.05359]
#  [-2.4055   1.78857  3.81884]
#  [-3.36271  1.99143  4.31718]
#  [-1.70027  1.40812  4.56998]
#  [-2.02561  2.74556  3.43894]
#  [-5.05127 -1.57136  1.68171]
#  [-4.04032  2.33109  1.55546]]
# ====================
# 57 Atoms(symbols='C5H7O2CH3', pbc=False)
# {'spin': 0, 'subset': 'FH51', 'subsetind': 1, 'species': 'methyl-d-valerolactone', 'count': 1, 'charge': 0, 'refweight': 1.83, 'refen': -6.45, 'energy': -6.45}
# ['C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'O', 'O', 'C', 'H', 'H', 'H']
# [[-3.18153 -1.0212   0.11446]
#  [-1.64311 -1.03863  0.12997]
#  [-0.99798  0.33509  0.34206]
#  [-3.18267  1.29677  0.98928]
#  [-3.71161 -0.10632  1.21642]
#  [-1.26758 -1.36787 -0.85065]
#  [-3.54164 -0.65255 -0.86011]
#  [-3.56503 -2.04721  0.22474]
#  [-3.41731  1.97049  1.82408]
#  [-3.61245  1.72856  0.0696 ]
#  [-3.40392 -0.46948  2.20954]
#  [-4.8118  -0.07236  1.21369]
#  [-1.73617  1.3628   0.85871]
#  [ 0.17738  0.53214  0.11954]
#  [-1.0744  -2.00861  1.18629]
#  [-1.40766 -3.03348  0.96936]
#  [ 0.02223 -1.98762  1.1758 ]
#  [-1.41087 -1.74894  2.20034]]
# ====================
# 58 Atoms(symbols='SiH', pbc=False)
# {'spin': 2, 'subset': 'G21EA', 'subsetind': 0, 'species': 'EA_14', 'count': -1, 'charge': -1, 'refweight': 1.69, 'refen': 29.3, 'energy': 29.3}
# ['Si', 'H']
# [[ 0.       0.       0.78299]
#  [ 0.       0.      -0.78299]]
# ====================
# 59 Atoms(symbols='SiH', pbc=False)
# {'spin': 1, 'subset': 'G21EA', 'subsetind': 0, 'species': 'EA_14n', 'count': 1, 'charge': 0, 'refweight': 1.69, 'refen': 29.3, 'energy': 29.3}
# ['Si', 'H']
# [[ 0.       0.       0.76713]
#  [ 0.       0.      -0.76713]]
# ====================
# 60 Atoms(symbols='Li', pbc=False)
# {'spin': 1, 'subset': 'G21IP', 'subsetind': 0, 'species': 'li', 'count': -1, 'charge': 0, 'refweight': 0.22, 'refen': 123.3, 'energy': 123.3}
# ['Li']
# [[0. 0. 0.]]
# ====================
# 61 Atoms(symbols='Li', pbc=False)
# {'spin': 0, 'subset': 'G21IP', 'subsetind': 0, 'species': 'li+', 'count': 1, 'charge': 1, 'refweight': 0.22, 'refen': 123.3, 'energy': 123.3}
# ['Li']
# [[0. 0. 0.]]
# ====================
# 62 Atoms(symbols='ClF', pbc=False)
# {'spin': 0, 'subset': 'G21IP', 'subsetind': 1, 'species': 51, 'count': -1, 'charge': 0, 'refweight': 0.22, 'refen': 291.699, 'energy': 291.699}
# ['Cl', 'F']
# [[ 0.       0.      -0.82875]
#  [ 0.       0.       0.82875]]
# ====================
# 63 Atoms(symbols='ClF', pbc=False)
# {'spin': 1, 'subset': 'G21IP', 'subsetind': 1, 'species': 'IP_79', 'count': 1, 'charge': 1, 'refweight': 0.22, 'refen': 291.699, 'energy': 291.699}
# ['Cl', 'F']
# [[ 0.       0.       0.77899]
#  [ 0.       0.      -0.77899]]
# ====================
# 64 Atoms(symbols='ClH', pbc=False)
# {'spin': 0, 'subset': 'G2RC', 'subsetind': 0, 'species': 22, 'count': 2, 'charge': 0, 'refweight': 1.11, 'refen': -48.52, 'energy': -48.52}
# ['Cl', 'H']
# [[ 0.       0.      -0.64148]
#  [ 0.       0.       0.64148]]
# ====================
# 65 Atoms(symbols='Cl2', pbc=False)
# {'spin': 0, 'subset': 'G2RC', 'subsetind': 0, 'species': 45, 'count': -2, 'charge': 0, 'refweight': 1.11, 'refen': -48.52, 'energy': -48.52}
# ['Cl', 'Cl']
# [[ 0.       0.       1.02117]
#  [ 0.       0.      -1.02117]]
# ====================
# 66 Atoms(symbols='CH4', pbc=False)
# {'spin': 0, 'subset': 'G2RC', 'subsetind': 0, 'species': 8, 'count': -1, 'charge': 0, 'refweight': 1.11, 'refen': -48.52, 'energy': -48.52}
# ['C', 'H', 'H', 'H', 'H']
# [[ 0.       0.       0.     ]
#  [ 0.62851 -0.62851  0.62851]
#  [-0.62851  0.62851  0.62851]
#  [-0.62851 -0.62851 -0.62851]
#  [ 0.62851  0.62851 -0.62851]]
# ====================
# 67 Atoms(symbols='ClCClH2', pbc=False)
# {'spin': 0, 'subset': 'G2RC', 'subsetind': 0, 'species': 97, 'count': 1, 'charge': 0, 'refweight': 1.11, 'refen': -48.52, 'energy': -48.52}
# ['Cl', 'C', 'Cl', 'H', 'H']
# [[ 0.       1.49399  0.83464]
#  [ 0.       0.      -0.1556 ]
#  [ 0.      -1.49399  0.83464]
#  [ 0.89865  0.      -0.75685]
#  [-0.89865  0.      -0.75685]]
# ====================
# 68 Atoms(symbols='ICF3', pbc=False)
# {'spin': 0, 'subset': 'HAL59', 'subsetind': 0, 'species': 'F3CI', 'count': 1, 'charge': 0, 'refweight': 12.38, 'refen': 0.89, 'energy': 0.89}
# ['I', 'C', 'F', 'F', 'F']
# [[ 0.       0.       0.96839]
#  [ 0.       0.      -1.17117]
#  [ 0.       1.24411 -1.64065]
#  [-1.07743 -0.62205 -1.64065]
#  [ 1.07743 -0.62205 -1.64065]]
# ====================
# 69 Atoms(symbols='PCH', pbc=False)
# {'spin': 0, 'subset': 'HAL59', 'subsetind': 0, 'species': 'PCH', 'count': 1, 'charge': 0, 'refweight': 12.38, 'refen': 0.89, 'energy': 0.89}
# ['P', 'C', 'H']
# [[ 0.       0.       0.5342 ]
#  [ 0.       0.      -0.99158]
#  [ 0.       0.      -2.06353]]
# ====================
# 70 Atoms(symbols='PCHICF3', pbc=False)
# {'spin': 0, 'subset': 'HAL59', 'subsetind': 0, 'species': 'PCH_F3CI', 'count': -1, 'charge': 0, 'refweight': 12.38, 'refen': 0.89, 'energy': 0.89}
# ['P', 'C', 'H', 'I', 'C', 'F', 'F', 'F']
# [[ 0.       0.      -3.62827]
#  [ 0.       0.      -5.15275]
#  [ 0.       0.      -6.22438]
#  [ 0.       0.       0.09563]
#  [ 0.       0.       2.23634]
#  [ 0.       1.24425  2.70662]
#  [-1.07756 -0.62213  2.70662]
#  [ 1.07756 -0.62213  2.70662]]
# ====================
# 71 Atoms(symbols='FI', pbc=False)
# {'spin': 0, 'subset': 'HAL59', 'subsetind': 1, 'species': 'FI', 'count': 1, 'charge': 0, 'refweight': 12.38, 'refen': 20.34, 'energy': 20.34}
# ['F', 'I']
# [[ 0.       0.      -1.64135]
#  [ 0.       0.       0.27872]]
# ====================
# 72 Atoms(symbols='FIC5NH5', pbc=False)
# {'spin': 0, 'subset': 'HAL59', 'subsetind': 1, 'species': 'FI_pyr', 'count': -1, 'charge': 0, 'refweight': 12.38, 'refen': 20.34, 'energy': 20.34}
# ['F', 'I', 'C', 'C', 'C', 'C', 'C', 'N', 'H', 'H', 'H', 'H', 'H']
# [[ 0.       0.       3.35156]
#  [ 0.       0.       1.37074]
#  [ 0.       1.14836 -1.73069]
#  [ 0.       1.19346 -3.11248]
#  [ 0.       0.      -3.81535]
#  [ 0.      -1.19346 -3.11248]
#  [ 0.      -1.14836 -1.73069]
#  [ 0.       0.      -1.05725]
#  [ 0.       2.05128 -1.13194]
#  [ 0.       2.14745 -3.62035]
#  [ 0.       0.      -4.89757]
#  [ 0.      -2.14745 -3.62035]
#  [ 0.      -2.05128 -1.13194]]
# ====================
# 73 Atoms(symbols='C5NH5', pbc=False)
# {'spin': 0, 'subset': 'HAL59', 'subsetind': 1, 'species': 'pyr', 'count': 1, 'charge': 0, 'refweight': 12.38, 'refen': 20.34, 'energy': 20.34}
# ['C', 'C', 'C', 'C', 'C', 'N', 'H', 'H', 'H', 'H', 'H']
# [[ 0.       1.13574  0.7175 ]
#  [ 0.       1.19066 -0.66811]
#  [ 0.       0.      -1.37494]
#  [ 0.      -1.19066 -0.66811]
#  [ 0.      -1.13574  0.7175 ]
#  [ 0.       0.       1.40899]
#  [ 0.       2.04991  1.30172]
#  [ 0.       2.14589 -1.17586]
#  [ 0.       0.      -2.45774]
#  [ 0.      -2.14589 -1.17586]
#  [ 0.      -2.04991  1.30172]]
# ====================
# 74 Atoms(symbols='BiH3', pbc=False)
# {'spin': 0, 'subset': 'HEAVY28', 'subsetind': 0, 'species': 'bih3', 'count': 1, 'charge': 0, 'refweight': 45.79, 'refen': 0.77, 'energy': 0.77}
# ['Bi', 'H', 'H', 'H']
# [[ 0.       0.76521  0.     ]
#  [ 1.43646 -0.25507  0.     ]
#  [-0.71823 -0.25507  1.24401]
#  [-0.71823 -0.25507 -1.24401]]
# ====================
# 75 Atoms(symbols='BiH3ClH', pbc=False)
# {'spin': 0, 'subset': 'HEAVY28', 'subsetind': 0, 'species': 'bih3_hcl', 'count': -1, 'charge': 0, 'refweight': 45.79, 'refen': 0.77, 'energy': 0.77}
# ['Bi', 'H', 'H', 'H', 'Cl', 'H']
# [[ 0.       0.       1.00001]
#  [-0.71818  1.24393  2.02126]
#  [-0.71818 -1.24393  2.02126]
#  [ 1.43636  0.       2.02126]
#  [ 0.       0.      -2.89551]
#  [ 0.       0.      -4.16828]]
# ====================
# 76 Atoms(symbols='HCl', pbc=False)
# {'spin': 0, 'subset': 'HEAVY28', 'subsetind': 0, 'species': 'hcl', 'count': 1, 'charge': 0, 'refweight': 45.79, 'refen': 0.77, 'energy': 0.77}
# ['H', 'Cl']
# [[ 0.       0.      -0.63571]
#  [ 0.       0.       0.63571]]
# ====================
# 77 Atoms(symbols='N3H5', pbc=False)
# {'spin': 0, 'subset': 'ICONF', 'subsetind': 0, 'species': 'N3H5_1', 'count': -1, 'charge': 0, 'refweight': 17.4, 'refen': 0.9, 'energy': 0.9}
# ['N', 'N', 'N', 'H', 'H', 'H', 'H', 'H']
# [[-0.77907  0.10995  0.     ]
#  [-0.0315   0.01698  1.22272]
#  [-0.0315   0.01698 -1.22272]
#  [ 0.73808 -0.65953 -1.13085]
#  [ 0.38904  0.93052 -1.38897]
#  [ 0.73808 -0.65953  1.13085]
#  [ 0.38904  0.93052  1.38897]
#  [-1.41216 -0.68588  0.     ]]
# ====================
# 78 Atoms(symbols='N3H5', pbc=False)
# {'spin': 0, 'subset': 'ICONF', 'subsetind': 0, 'species': 'N3H5_2', 'count': 1, 'charge': 0, 'refweight': 17.4, 'refen': 0.9, 'energy': 0.9}
# ['N', 'N', 'N', 'H', 'H', 'H', 'H', 'H']
# [[-0.17184 -0.55707  0.30027]
#  [ 1.20115 -0.58382 -0.10375]
#  [-0.75672  0.76299  0.15936]
#  [-1.28143  0.84593 -0.71555]
#  [-1.41635  0.87959  0.92732]
#  [ 1.34068  0.03521 -0.9108 ]
#  [ 1.72996 -0.17035  0.66352]
#  [-0.64546 -1.21246 -0.32037]]
# ====================
# 79 Atoms(symbols='CNC3H12Cl', pbc=False)
# {'spin': 0, 'subset': 'IL16', 'subsetind': 0, 'species': 202, 'count': 1, 'charge': 0, 'refweight': 0.52, 'refen': -113.51, 'energy': -113.51}
# ['C', 'N', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'Cl']
# [[ 1.39869  0.0046  -0.35986]
#  [-0.04092 -0.16968  0.01657]
#  [-0.94691  0.94573 -0.45919]
#  [-1.09281  1.05636 -1.97615]
#  [-0.54728 -1.54568 -0.29192]
#  [-0.06025 -0.1049   1.043  ]
#  [-0.45644 -1.76195 -1.36093]
#  [ 0.04287 -2.25341  0.29679]
#  [ 1.70632  1.01947 -0.09298]
#  [ 1.98295 -0.70513  0.23272]
#  [-0.5342   1.8617  -0.02018]
#  [-1.91068  0.76604  0.03222]
#  [ 1.54446 -0.17403 -1.42987]
#  [-1.59123 -1.61045  0.02723]
#  [-1.76588  1.89143 -2.20731]
#  [-0.1349   1.25942 -2.4697 ]
#  [-1.5278   0.1512  -2.41652]
#  [-0.06296 -0.03803  2.86058]]
# ====================
# 80 Atoms(symbols='CNC3H12', pbc=False)
# {'spin': 0, 'subset': 'IL16', 'subsetind': 0, 'species': '202A', 'count': -1, 'charge': 1, 'refweight': 0.52, 'refen': -113.51, 'energy': -113.51}
# ['C', 'N', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[ 1.39869  0.0046  -0.35986]
#  [-0.04092 -0.16968  0.01657]
#  [-0.94691  0.94573 -0.45919]
#  [-1.09281  1.05636 -1.97615]
#  [-0.54728 -1.54568 -0.29192]
#  [-0.06025 -0.1049   1.043  ]
#  [-0.45644 -1.76195 -1.36093]
#  [ 0.04287 -2.25341  0.29679]
#  [ 1.70632  1.01947 -0.09298]
#  [ 1.98295 -0.70513  0.23272]
#  [-0.5342   1.8617  -0.02018]
#  [-1.91068  0.76604  0.03222]
#  [ 1.54446 -0.17403 -1.42987]
#  [-1.59123 -1.61045  0.02723]
#  [-1.76588  1.89143 -2.20731]
#  [-0.1349   1.25942 -2.4697 ]
#  [-1.5278   0.1512  -2.41652]]
# ====================
# 81 Atoms(symbols='Cl', pbc=False)
# {'spin': 0, 'subset': 'IL16', 'subsetind': 0, 'species': '202B', 'count': -1, 'charge': -1, 'refweight': 0.52, 'refen': -113.51, 'energy': -113.51}
# ['Cl']
# [[-0.06296 -0.03803  2.86058]]
# ====================
# 82 Atoms(symbols='C2NH3', pbc=False)
# {'spin': 0, 'subset': 'ISO34', 'subsetind': 0, 'species': 'E14', 'count': -1, 'charge': 0, 'refweight': 3.9, 'refen': 24.58, 'energy': 24.58}
# ['C', 'C', 'N', 'H', 'H', 'H']
# [[ 0.       0.       0.48865]
#  [ 0.       0.      -0.96688]
#  [ 0.       0.      -2.11788]
#  [ 0.51196 -0.88674  0.86537]
#  [ 0.51196  0.88674  0.86537]
#  [-1.02392  0.       0.86537]]
# ====================
# 83 Atoms(symbols='CNCH3', pbc=False)
# {'spin': 0, 'subset': 'ISO34', 'subsetind': 0, 'species': 'P14', 'count': 1, 'charge': 0, 'refweight': 3.9, 'refen': 24.58, 'energy': 24.58}
# ['C', 'N', 'C', 'H', 'H', 'H']
# [[ 0.       0.       0.48303]
#  [ 0.       0.      -0.93725]
#  [ 0.       0.      -2.10376]
#  [ 0.51296 -0.88846  0.85266]
#  [ 0.51296  0.88846  0.85266]
#  [-1.02591  0.       0.85266]]
# ====================
# 84 Atoms(symbols='H2CBHPOClAlPBHFPHP', pbc=False)
# {'spin': 0, 'subset': 'MB16-43', 'subsetind': 0, 'species': 31, 'count': -2, 'charge': 0, 'refweight': 0.12, 'refen': 534.9003, 'energy': 534.9003}
# ['H', 'H', 'C', 'B', 'H', 'P', 'O', 'Cl', 'Al', 'P', 'B', 'H', 'F', 'P', 'H', 'P']
# [[ 1.47786  2.02674 -1.47792]
#  [-0.75909  0.22976  2.93087]
#  [-1.72654 -1.32635 -0.82886]
#  [ 1.13534 -0.4699  -1.18849]
#  [-2.27669 -2.08301 -0.25893]
#  [ 0.03232 -2.02393 -1.17654]
#  [ 0.21785  0.30748  2.94675]
#  [ 2.3356   2.0771   1.36507]
#  [ 0.70755  0.74188  1.04528]
#  [ 1.63168  0.91294 -2.34249]
#  [-1.59995  0.02349 -0.14624]
#  [ 0.59008 -0.51657  3.30981]
#  [ 0.32777  1.1531  -3.28767]
#  [-1.4155   1.58846  0.55584]
#  [-2.18646 -1.23947 -1.82225]
#  [ 1.50819 -1.40171  0.37577]]
# ====================
# 85 Atoms(symbols='AlH3', pbc=False)
# {'spin': 0, 'subset': 'MB16-43', 'subsetind': 0, 'species': 'AlH3', 'count': 2, 'charge': 0, 'refweight': 0.12, 'refen': 534.9003, 'energy': 534.9003}
# ['Al', 'H', 'H', 'H']
# [[-0.       0.       0.     ]
#  [-0.79265  1.37291  0.     ]
#  [-0.79265 -1.37291  0.     ]
#  [ 1.5853   0.       0.     ]]
# ====================
# 86 Atoms(symbols='BH3', pbc=False)
# ...
# {'spin': 0, 'subset': 'UPU23', 'subsetind': 0, 'species': '2p', 'count': -1, 'charge': -1, 'refweight': 9.93, 'refen': 0.57, 'energy': 0.57}
# ['H', 'O', 'C', 'H', 'H', 'C', 'H', 'O', 'C', 'H', 'N', 'C', 'H', 'C', 'H', 'C', 'O', 'N', 'H', 'C', 'O', 'C', 'H', 'C', 'H', 'O', 'H', 'O', 'P', 'O', 'O', 'O', 'C', 'H', 'H', 'C', 'H', 'O', 'C', 'H', 'N', 'C', 'H', 'C', 'H', 'C', 'O', 'N', 'H', 'C', 'O', 'C', 'H', 'C', 'H', 'O', 'H', 'O', 'H']
# [[-2.80046 -1.43976  2.79369]
#  [-2.66581 -1.10811  1.89154]
#  [-2.57946 -2.23922  1.00495]
#  [-3.46948 -2.87354  1.09875]
#  [-1.68807 -2.84166  1.22604]
#  [-2.47105 -1.72735 -0.41735]
#  [-2.26439 -2.57562 -1.07617]
#  [-3.73685 -1.13182 -0.84138]
#  [-3.54573  0.23165 -1.20432]
#  [-3.54228  0.36211 -2.28942]
#  [-4.69289  0.99888 -0.70695]
#  [-4.99862  0.94244  0.63323]
#  [-4.3421   0.30266  1.21795]
#  [-6.04329  1.61164  1.17477]
#  [-6.25724  1.54294  2.23279]
#  [-6.89177  2.41974  0.3337 ]
#  [-7.86961  3.08447  0.69567]
#  [-6.52716  2.39612 -1.02075]
#  [-7.10135  2.94169 -1.65864]
#  [-5.47378  1.72466 -1.60765]
#  [-5.2543   1.76713 -2.81634]
#  [-1.39945 -0.65022 -0.6187 ]
#  [-0.62081 -0.68203  0.14621]
#  [-2.19661  0.66042 -0.59057]
#  [-2.34024  0.97237  0.4461 ]
#  [-1.58148  1.73639 -1.27668]
#  [-1.17335  1.34386 -2.073  ]
#  [-0.8201  -0.75475 -1.93561]
#  [ 0.63574 -1.52533 -2.05811]
#  [ 0.9186  -1.56887 -3.52865]
#  [ 0.63046 -2.74288 -1.18608]
#  [ 1.657   -0.48962 -1.31082]
#  [ 1.95362  0.79727 -1.89359]
#  [ 1.24447  1.53804 -1.50986]
#  [ 1.87633  0.74065 -2.98487]
#  [ 3.37033  1.17531 -1.50595]
#  [ 3.62738  2.13044 -1.97503]
#  [ 3.46721  1.35218 -0.05849]
#  [ 4.36411  0.38659  0.4946 ]
#  [ 5.31528  0.85388  0.76019]
#  [ 3.80556 -0.10375  1.75729]
#  [ 2.64962 -0.85266  1.75172]
#  [ 2.23009 -1.03219  0.76704]
#  [ 2.06607 -1.31048  2.88405]
#  [ 1.16181 -1.90359  2.8465 ]
#  [ 2.64489 -0.99591  4.16722]
#  [ 2.21897 -1.34744  5.27318]
#  [ 3.78595 -0.18364  4.08598]
#  [ 4.2144   0.09242  4.96647]
#  [ 4.40783  0.29987  2.95347]
#  [ 5.39232  1.03374  3.00493]
#  [ 4.40666  0.10671 -1.87833]
#  [ 4.07028 -0.52165 -2.7052 ]
#  [ 4.58357 -0.69631 -0.57916]
#  [ 3.81441 -1.46794 -0.51775]
#  [ 5.84714 -1.32965 -0.47956]
#  [ 6.45967 -0.74835 -0.97737]
#  [ 5.68305  0.70043 -2.18746]
#  [ 5.84493  0.59765 -3.13824]]
# ====================
# 113 Atoms(symbols='HOCH2CHOCHNCHCHCONHCOCHCHOHOPO3CH2CHOCHNCHCHCONHCOCHCHOHOH', pbc=False)
# {'spin': 0, 'subset': 'UPU23', 'subsetind': 0, 'species': '5z', 'count': 1, 'charge': -1, 'refweight': 9.93, 'refen': 0.57, 'energy': 0.57}
# ['H', 'O', 'C', 'H', 'H', 'C', 'H', 'O', 'C', 'H', 'N', 'C', 'H', 'C', 'H', 'C', 'O', 'N', 'H', 'C', 'O', 'C', 'H', 'C', 'H', 'O', 'H', 'O', 'P', 'O', 'O', 'O', 'C', 'H', 'H', 'C', 'H', 'O', 'C', 'H', 'N', 'C', 'H', 'C', 'H', 'C', 'O', 'N', 'H', 'C', 'O', 'C', 'H', 'C', 'H', 'O', 'H', 'O', 'H']
# [[-0.34175  3.11994  1.77649]
#  [-0.4276   2.16773  1.93885]
#  [ 0.2908   1.83886  3.13794]
#  [-0.21316  2.25264  4.0204 ]
#  [ 1.31686  2.22685  3.10226]
#  [ 0.37262  0.33319  3.24579]
#  [ 0.95568  0.07263  4.13811]
#  [-0.95633 -0.23899  3.35969]
#  [-1.00734 -1.50358  2.71436]
#  [-1.30952 -2.28645  3.41056]
#  [-2.06356 -1.44879  1.66486]
#  [-2.33811 -0.28543  0.98833]
#  [-1.7547   0.57572  1.30055]
#  [-3.2876  -0.20895  0.02211]
#  [-3.47405  0.7238  -0.49277]
#  [-4.05945 -1.37511 -0.32988]
#  [-4.95208 -1.44458 -1.18228]
#  [-3.68871 -2.52423  0.38708]
#  [-4.17767 -3.38586  0.15852]
#  [-2.72657 -2.63946  1.36741]
#  [-2.46687 -3.70176  1.93027]
#  [ 0.98135 -0.36543  2.03179]
#  [ 0.66395  0.12088  1.10635]
#  [ 0.39436 -1.78175  2.14263]
#  [ 0.35321 -2.30807  1.18518]
#  [ 1.11786 -2.53898  3.11295]
#  [ 2.05199 -2.26666  3.02244]
#  [ 2.40245 -0.33806  2.15168]
#  [ 3.36193 -0.37555  0.81329]
#  [ 3.08372 -1.61967  0.01791]
#  [ 4.74671 -0.06256  1.28972]
#  [ 2.69746  0.91084  0.03934]
#  [ 3.43659  1.49982 -1.05323]
#  [ 4.0731   0.74913 -1.53493]
#  [ 4.06856  2.30769 -0.6674 ]
#  [ 2.46531  2.06113 -2.07391]
#  [ 3.03841  2.61629 -2.82443]
#  [ 1.78033  0.96948 -2.76207]
#  [ 0.37449  1.09055 -2.61054]
#  [-0.10398  1.50531 -3.50158]
#  [-0.17371 -0.2704  -2.44565]
#  [ 0.52213 -1.21335 -1.73088]
#  [ 1.47823 -0.8949  -1.32851]
#  [ 0.06746 -2.4782  -1.54862]
#  [ 0.66118 -3.19854 -1.00208]
#  [-1.19626 -2.87902 -2.10859]
#  [-1.72775 -3.99212 -2.02193]
#  [-1.84855 -1.84719 -2.80296]
#  [-2.75351 -2.07051 -3.20883]
#  [-1.41821 -0.55102 -3.00988]
#  [-2.07766  0.273   -3.63807]
#  [ 1.36351  2.95582 -1.49111]
#  [ 1.64205  3.38676 -0.52684]
#  [ 0.1652   2.00398 -1.38084]
#  [ 0.26132  1.41095 -0.46956]
#  [-1.0818   2.6653  -1.34135]
#  [-0.96696  3.46331 -1.89574]
#  [ 0.96948  3.98781 -2.41378]
#  [ 1.43516  4.80574 -2.1786 ]]
# ====================
# 114 Atoms(symbols='H', pbc=False)
# {'spin': 1, 'subset': 'W4-11', 'subsetind': 0, 'species': 'h', 'count': 6, 'charge': 0, 'refweight': 0.19, 'refen': 535.885, 'energy': 535.885}
# ['H']
# [[0. 0. 0.]]
# ====================
# 115 Atoms(symbols='Si', pbc=False)
# {'spin': 2, 'subset': 'W4-11', 'subsetind': 0, 'species': 'si', 'count': 2, 'charge': 0, 'refweight': 0.19, 'refen': 535.885, 'energy': 535.885}
# ['Si']
# [[0. 0. 0.]]
# ====================
# 116 Atoms(symbols='SiH3SiH3', pbc=False)
# {'spin': 0, 'subset': 'W4-11', 'subsetind': 0, 'species': 'si2h6', 'count': -1, 'charge': 0, 'refweight': 0.19, 'refen': 535.885, 'energy': 535.885}
# ['Si', 'H', 'H', 'H', 'Si', 'H', 'H', 'H']
# [[ 0.       1.17088  0.     ]
#  [-1.38995  1.68512  0.     ]
#  [ 0.69546  1.68369  1.20405]
#  [ 0.69546  1.68369 -1.20405]
#  [ 0.      -1.17088  0.     ]
#  [ 1.38995 -1.68512  0.     ]
#  [-0.69546 -1.68369  1.20405]
#  [-0.69546 -1.68369 -1.20405]]
# ====================
# 117 Atoms(symbols='H', pbc=False)
# {'spin': 1, 'subset': 'W4-11', 'subsetind': 1, 'species': 'h', 'count': 3, 'charge': 0, 'refweight': 0.19, 'refen': 242.267, 'energy': 242.267}
# ['H']
# [[0. 0. 0.]]
# ====================
# 118 Atoms(symbols='P', pbc=False)
# {'spin': 3, 'subset': 'W4-11', 'subsetind': 1, 'species': 'p', 'count': 1, 'charge': 0, 'refweight': 0.19, 'refen': 242.267, 'energy': 242.267}
# ['P']
# [[0. 0. 0.]]
# ====================
# 119 Atoms(symbols='PH3', pbc=False)
# {'spin': 0, 'subset': 'W4-11', 'subsetind': 1, 'species': 'ph3', 'count': -1, 'charge': 0, 'refweight': 0.19, 'refen': 242.267, 'energy': 242.267}
# ['P', 'H', 'H', 'H']
# [[ 0.       0.       0.12741]
#  [ 0.       1.19034 -0.63704]
#  [-1.03087 -0.59517 -0.63704]
#  [ 1.03087 -0.59517 -0.63704]]
# ====================
# 120 Atoms(symbols='Al', pbc=False)
# {'spin': 1, 'subset': 'W4-11', 'subsetind': 2, 'species': 'al', 'count': 1, 'charge': 0, 'refweight': 0.19, 'refen': 430.967, 'energy': 430.967}
# ['Al']
# [[0. 0. 0.]]
# ====================
# 121 Atoms(symbols='AlF3', pbc=False)
# {'spin': 0, 'subset': 'W4-11', 'subsetind': 2, 'species': 'alf3', 'count': -1, 'charge': 0, 'refweight': 0.19, 'refen': 430.967, 'energy': 430.967}
# ['Al', 'F', 'F', 'F']
# [[ 0.       0.       0.     ]
#  [ 0.       1.63177  0.     ]
#  [ 1.41315 -0.81588  0.     ]
#  [-1.41315 -0.81588  0.     ]]
# ====================
# 122 Atoms(symbols='F', pbc=False)
# {'spin': 1, 'subset': 'W4-11', 'subsetind': 2, 'species': 'f', 'count': 3, 'charge': 0, 'refweight': 0.19, 'refen': 430.967, 'energy': 430.967}
# ['F']
# [[0. 0. 0.]]
# ====================
# 123 Atoms(symbols='C', pbc=False)
# {'spin': 2, 'subset': 'W4-11', 'subsetind': 3, 'species': 'c', 'count': 1, 'charge': 0, 'refweight': 0.19, 'refen': 439.441, 'energy': 439.441}
# ['C']
# [[0. 0. 0.]]
# ====================
# 124 Atoms(symbols='CNH3', pbc=False)
# {'spin': 0, 'subset': 'W4-11', 'subsetind': 3, 'species': 'ch2nh', 'count': -1, 'charge': 0, 'refweight': 0.19, 'refen': 439.441, 'energy': 439.441}
# ['C', 'N', 'H', 'H', 'H']
# [[ 0.05658  0.58765  0.     ]
#  [ 0.05658 -0.68651  0.     ]
#  [-0.90231 -1.03426  0.     ]
#  [-0.84382  1.20459  0.     ]
#  [ 1.01054  1.10932  0.     ]]
# ====================
# 125 Atoms(symbols='H', pbc=False)
# {'spin': 1, 'subset': 'W4-11', 'subsetind': 3, 'species': 'h', 'count': 3, 'charge': 0, 'refweight': 0.19, 'refen': 439.441, 'energy': 439.441}
# ['H']
# [[0. 0. 0.]]
# ====================
# 126 Atoms(symbols='N', pbc=False)
# {'spin': 3, 'subset': 'W4-11', 'subsetind': 3, 'species': 'n', 'count': 1, 'charge': 0, 'refweight': 0.19, 'refen': 439.441, 'energy': 439.441}
# ['N']
# [[0. 0. 0.]]
# ====================
# 127 Atoms(symbols='OH2', pbc=False)
# {'spin': 0, 'subset': 'WATER27', 'subsetind': 0, 'species': 'H2O', 'count': 20, 'charge': 0, 'refweight': 0.7, 'refen': 208.0, 'energy': 208.0}
# ['O', 'H', 'H']
# [[ 0.       0.      -0.38936]
#  [ 0.76298  0.       0.19468]
#  [-0.76298  0.       0.19468]]
# ====================
# 128 Atoms(symbols='O20H40', pbc=False)
# {'spin': 0, 'subset': 'WATER27', 'subsetind': 0, 'species': 'H2O20fc', 'count': -1, 'charge': 0, 'refweight': 0.7, 'refen': 208.0, 'energy': 208.0}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# [[-4.07000e-03  1.93708e+00 -5.68375e+00]
#  [-2.00810e+00 -1.38540e-01 -5.73518e+00]
#  [-1.38540e-01  2.00810e+00  5.73518e+00]
#  [-1.93708e+00 -4.07000e-03  5.68375e+00]
#  [-1.97377e+00  2.27500e-02  2.80813e+00]
#  [ 1.97377e+00 -2.27500e-02  2.80813e+00]
#  [-1.96877e+00  2.15600e-02 -2.89395e+00]
#  [ 1.96877e+00 -2.15600e-02 -2.89395e+00]
#  [ 4.07000e-03 -1.93708e+00 -5.68375e+00]
#  [ 2.00810e+00  1.38540e-01 -5.73518e+00]
#  [ 1.38540e-01 -2.00810e+00  5.73518e+00]
#  [ 1.93708e+00  4.07000e-03  5.68375e+00]
#  [ 1.98093e+00  8.91800e-02 -4.43900e-02]
#  [ 2.27500e-02  1.97377e+00 -2.80813e+00]
#  [ 2.15600e-02  1.96877e+00  2.89395e+00]
#  [-2.15600e-02 -1.96877e+00  2.89395e+00]
#  [-8.91800e-02  1.98093e+00  4.43900e-02]
#  [ 8.91800e-02 -1.98093e+00  4.43900e-02]
#  [-2.27500e-02 -1.97377e+00 -2.80813e+00]
#  [-1.98093e+00 -8.91800e-02 -4.43900e-02]
#  [-7.95320e-01  1.38382e+00 -5.80381e+00]
#  [-5.29900e-02  2.25335e+00 -4.76722e+00]
#  [-1.33023e+00 -8.60570e-01 -5.78903e+00]
#  [-2.66723e+00 -3.20230e-01 -6.40995e+00]
#  [-3.20230e-01  2.66723e+00  6.40995e+00]
#  [-8.60570e-01  1.33023e+00  5.78903e+00]
#  [-1.38382e+00 -7.95320e-01  5.80381e+00]
#  [-2.25335e+00 -5.29900e-02  4.76722e+00]
#  [-2.36753e+00 -4.91000e-03  1.92172e+00]
#  [-1.35126e+00  7.81490e-01  2.79460e+00]
#  [ 2.36753e+00  4.91000e-03  1.92172e+00]
#  [ 1.35126e+00 -7.81490e-01  2.79460e+00]
#  [-2.29317e+00 -3.16100e-02 -3.80937e+00]
#  [-1.34965e+00  7.82940e-01 -2.88703e+00]
#  [ 1.34965e+00 -7.82940e-01 -2.88703e+00]
#  [ 2.29317e+00  3.16100e-02 -3.80937e+00]
#  [ 5.29900e-02 -2.25335e+00 -4.76722e+00]
#  [ 7.95320e-01 -1.38382e+00 -5.80381e+00]
#  [ 1.33023e+00  8.60570e-01 -5.78903e+00]
#  [ 2.66723e+00  3.20230e-01 -6.40995e+00]
#  [ 8.60570e-01 -1.33023e+00  5.78903e+00]
#  [ 3.20230e-01 -2.66723e+00  6.40995e+00]
#  [ 1.38382e+00  7.95320e-01  5.80381e+00]
#  [ 2.25335e+00  5.29900e-02  4.76722e+00]
#  [ 1.33572e+00  8.27960e-01 -4.22800e-02]
#  [ 2.35281e+00  7.83200e-02 -9.41140e-01]
#  [-4.91000e-03  2.36753e+00 -1.92172e+00]
#  [ 7.81490e-01  1.35126e+00 -2.79460e+00]
#  [ 7.82940e-01  1.34965e+00  2.88703e+00]
#  [-3.16100e-02  2.29317e+00  3.80937e+00]
#  [ 3.16100e-02 -2.29317e+00  3.80937e+00]
#  [-7.82940e-01 -1.34965e+00  2.88703e+00]
#  [-8.27960e-01  1.33572e+00  4.22800e-02]
#  [-7.83200e-02  2.35281e+00  9.41140e-01]
#  [ 7.83200e-02 -2.35281e+00  9.41140e-01]
#  [ 8.27960e-01 -1.33572e+00  4.22800e-02]
#  [ 4.91000e-03 -2.36753e+00 -1.92172e+00]
#  [-7.81490e-01 -1.35126e+00 -2.79460e+00]
#  [-2.35281e+00 -7.83200e-02 -9.41140e-01]
#  [-1.33572e+00 -8.27960e-01 -4.22800e-02]]
# ====================
# 129 Atoms(symbols='CH2O2', pbc=False)
# {'spin': 0, 'subset': 'WCPT18', 'subsetind': 0, 'species': 'reac1', 'count': -1, 'charge': 0, 'refweight': 1.62, 'refen': 36.76, 'energy': 36.76}
# ['C', 'H', 'H', 'O', 'O']
# [[ 0.       0.42103  0.     ]
#  [-0.38306  1.44804  0.     ]
#  [-0.65956 -1.34364  0.     ]
#  [ 1.15852  0.11709  0.     ]
#  [-1.02819 -0.44591  0.     ]]
# ====================
# 130 Atoms(symbols='CH2O2', pbc=False)
# {'spin': 0, 'subset': 'WCPT18', 'subsetind': 0, 'species': 'ts1', 'count': 1, 'charge': 0, 'refweight': 1.62, 'refen': 36.76, 'energy': 36.76}
# ['C', 'H', 'H', 'O', 'O']
# [[ 0.       0.       0.48976]
#  [ 0.       0.       1.57678]
#  [ 0.       0.      -1.01893]
#  [ 0.       1.04748 -0.21852]
#  [ 0.      -1.04748 -0.21852]]
# ====================
# 131 Atoms(symbols='CB2H4', pbc=False)
# {'spin': 0, 'subset': 'YBDE18', 'subsetind': 0, 'species': 'cbh22', 'count': 1, 'charge': 0, 'refweight': 1.15, 'refen': 42.11, 'energy': 42.11}
# ['C', 'B', 'B', 'H', 'H', 'H', 'H']
# [[ 0.       0.       0.     ]
#  [ 0.       0.       1.43043]
#  [ 0.       0.      -1.43043]
#  [ 0.       1.04835  1.99345]
#  [ 0.      -1.04835  1.99345]
#  [ 0.       1.04835 -1.99345]
#  [ 0.      -1.04835 -1.99345]]
# ====================
# 132 Atoms(symbols='NCH3CH3CH3', pbc=False)
# {'spin': 0, 'subset': 'YBDE18', 'subsetind': 0, 'species': 'nme3', 'count': 1, 'charge': 0, 'refweight': 1.15, 'refen': 42.11, 'energy': 42.11}
# ['N', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H']
# [[ 0.       0.       0.40681]
#  [ 0.       1.37311 -0.06554]
#  [ 0.       1.43156 -1.16702]
#  [-0.88452  1.88977  0.30552]
#  [ 0.88452  1.88977  0.30552]
#  [-1.18915 -0.68656 -0.06554]
#  [-1.23977 -0.71578 -1.16702]
#  [-1.19433 -1.7109   0.30552]
#  [-2.07885 -0.17887  0.30552]
#  [ 1.18915 -0.68656 -0.06554]
#  [ 1.23977 -0.71578 -1.16702]
#  [ 2.07885 -0.17887  0.30552]
#  [ 1.19433 -1.7109   0.30552]]
# ====================
# 133 Atoms(symbols='CNB2H4CH3CH3CH3', pbc=False)
# {'spin': 0, 'subset': 'YBDE18', 'subsetind': 0, 'species': 'nme3-cbh22', 'count': -1, 'charge': 0, 'refweight': 1.15, 'refen': 42.11, 'energy': 42.11}
# ['C', 'N', 'B', 'B', 'H', 'H', 'H', 'H', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H']
# [[ 0.24962 -1.00062  0.     ]
#  [-0.09479  0.48214  0.     ]
#  [ 1.66739 -1.46639  0.     ]
#  [-0.89685 -1.95857  0.     ]
#  [ 1.84009 -2.64651  0.     ]
#  [ 2.63548 -0.75794  0.     ]
#  [-2.05327 -1.61541  0.     ]
#  [-0.66322 -3.12671  0.     ]
#  [-0.89685  0.81567  1.21098]
#  [-1.14765  1.8768   1.19642]
#  [-1.79404  0.20645  1.20165]
#  [-0.29502  0.57077  2.08135]
#  [-0.89685  0.81567 -1.21098]
#  [-1.14765  1.8768  -1.19642]
#  [-0.29502  0.57077 -2.08135]
#  [-1.79404  0.20645 -1.20165]
#  [ 1.10477  1.35547  0.     ]
#  [ 0.77336  2.39306  0.     ]
#  [ 1.69381  1.13911  0.88496]
#  [ 1.69381  1.13911 -0.88496]]
# ====================
# 134 Atoms(symbols='CH2', pbc=False)
# {'spin': 2, 'subset': 'YBDE18', 'subsetind': 1, 'species': 'ch2', 'count': 1, 'charge': 0, 'refweight': 1.15, 'refen': 42.81, 'energy': 42.81}
# ['C', 'H', 'H']
# [[ 0.       0.       0.10728]
#  [ 0.       0.98455 -0.32184]
#  [ 0.      -0.98455 -0.32184]]
# ====================
# 135 Atoms(symbols='NCH3CH3CH3', pbc=False)
# {'spin': 0, 'subset': 'YBDE18', 'subsetind': 1, 'species': 'nme3', 'count': 1, 'charge': 0, 'refweight': 1.15, 'refen': 42.81, 'energy': 42.81}
# ['N', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H']
# [[ 0.       0.       0.40681]
#  [ 0.       1.37311 -0.06554]
#  [ 0.       1.43156 -1.16702]
#  [-0.88452  1.88977  0.30552]
#  [ 0.88452  1.88977  0.30552]
#  [-1.18915 -0.68656 -0.06554]
#  [-1.23977 -0.71578 -1.16702]
#  [-1.19433 -1.7109   0.30552]
#  [-2.07885 -0.17887  0.30552]
#  [ 1.18915 -0.68656 -0.06554]
#  [ 1.23977 -0.71578 -1.16702]
#  [ 2.07885 -0.17887  0.30552]
#  [ 1.19433 -1.7109   0.30552]]
# ====================
# 136 Atoms(symbols='CNH2CH3CH3CH3', pbc=False)
# {'spin': 0, 'subset': 'YBDE18', 'subsetind': 1, 'species': 'nme3-ch2', 'count': -1, 'charge': 0, 'refweight': 1.15, 'refen': 42.81, 'energy': 42.81}
# ['C', 'N', 'H', 'H', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'H']
# [[ 0.54982  1.46913  0.     ]
#  [ 0.01881  0.04592  0.     ]
#  [ 0.08336  1.92801  0.88309]
#  [ 0.08336  1.92801 -0.88309]
#  [ 0.54982 -0.63341  1.20287]
#  [ 0.22431 -1.67428  1.21568]
#  [ 1.63125 -0.55013  1.17062]
#  [ 0.17428 -0.10884  2.07776]
#  [ 0.54982 -0.63341 -1.20287]
#  [ 0.22431 -1.67428 -1.21568]
#  [ 0.17428 -0.10884 -2.07776]
#  [ 1.63125 -0.55013 -1.17062]
#  [-1.46686 -0.07623  0.     ]
#  [-1.77559 -1.12478  0.     ]
#  [-1.83904  0.42866  0.88681]
#  [-1.83904  0.42866 -0.88681]]

# %%
def local_eval_xc_gga_j2(xc_code, rho, spin=0, relativity=0, deriv=1, omega=None, verbose=None,
                   xcmodel=None):
    # we only expect there to be a rho0 array, but I unpack it as (rho, deriv) here to be in line with the
    # pyscf example -- the size of the 'rho' array depends on the xc type (LDA, GGA, etc.)
    # so since LDA calculation, check for size first.
    try:
        rhoshape = len(rho.shape)
        pol = 3
    except:
        rhoshape = len(rho)
        pol = 2
    #if len of shape == 3, spin polarized so compress to unpolarized for calculation
    if rhoshape != pol:    
        #SPIN-UNPOLARIZED, ALL ARRAYS PASSED AS IS TO LIBXC
        try:
            # print("unpacking rho[:4] into rho0, dx, dy, dz")
            rho0, dx, dy, dz = rho[:4]
            sigma = jnp.array(dx**2+dy**2+dz**2)
        except:
            print("Unpacking failed...")
            rho0, drho = rho[:4]
            sigma = jnp.array(drho**2)
        rho0 = jnp.array(rho0)
        rhosig = jnp.stack([rho0, sigma], axis=1)
        # print('rho/sig/rhosig shapes: ', rho0.shape, sigma.shape, rhosig.shape)
        # calculate the "custom" energy with rho -- THIS IS e
        # cast back to np.array since that's what pyscf works with
        # pass as tuple -- (rho, sigma)
        exc = jax.vmap(xcmodel)(rhosig)
        exc = jnp.array(exc)/rho0
        vrho_f = eqx.filter_grad(xcmodel)
        vrhosigma = jnp.array(jax.vmap(vrho_f)(rhosig))
        #vxc = vrho and vsigma, unpolarized, followed by nothing higher order in GGA
        vxc = (vrhosigma[:, 0], vrhosigma[:, 1], None, None)
    
        v2_f = jax.hessian(xcmodel)
        v2 = jnp.array(jax.vmap(v2_f)(rhosig))
        # print('v2 shape', v2.shape)
        v2rho2 = v2[:, 0, 0]
        v2rhosigma = v2[:, 0, 1]
        v2sigma2 = v2[:, 1, 1]
        v2lapl2 = None
        vtau2 = None
        v2rholapl = None
        v2rhotau = None
        v2lapltau = None
        v2sigmalapl = None
        v2sigmatau = None
        # 2nd order functional derivative
        fxc = (v2rho2, v2rhosigma, v2sigma2, v2lapl2, vtau2, v2rholapl, v2rhotau, v2lapltau, v2sigmalapl, v2sigmatau)
        # 3rd order
        kxc = None

    else:
        #SPIN POLARIZED; RESULT ARRAYS MUST BE RETURNED SPIN POLARIZED
        #THIS IS HACKY -- THE NETWORK IS NOT ARCHITECTED TO ACCEPT ALL THE POLARIZED PARAMETERS, SO THE GRADIENTS ARE JUST DUPLICATED IN THE RETURN;
        #GENERATE A FUNCTION THAT COMBINES THEN CALLS
        def make_epsilon_function(model):
            #importantly, do not place the vmap here
            def get_epsilon(arr):
                rhou, rhod, sigma1, sigma2, sigma3 = arr
                rho0 = jnp.array(rhou+rhod)
                #sum the sigma contributions
                sumsigma = sigma1+sigma2+sigma3

                rhosig = jnp.stack([rho0, sumsigma])
                # calculate the "custom" energy with rho -- THIS IS e
                # cast back to np.array since that's what pyscf works with
                # pass as tuple -- (rho, sigma)
                exc = model(rhosig)
                return exc
            return get_epsilon
                
        # model_epsilon = partial(get_epsilon, model=xcmodel)
        model_epsilon = make_epsilon_function(model=xcmodel)
        rho_u, rho_d = rho
        # print('rho_u, rho_d shapes:', rho_u.shape, rho_d.shape)
        rho0u, dxu, dyu, dzu = rho_u[:4]
        rho0d, dxd, dyd, dzd = rho_d[:4]
        #up-up
        dxu2 = dxu*dxu
        dyu2 = dyu*dyu
        dzu2 = dzu*dzu
        #up-down
        dxud = dxu*dxd
        dyud = dyu*dyd
        dzud = dzu*dzd
        #down-down
        dxd2 = dxd*dxd
        dyd2 = dyd*dyd
        dzd2 = dzd*dzd
        sigma1 = dxu2+dyu2+dzu2
        sigma2 = dxud+dyud+dzud
        sigma3 = dxd2+dyd2+dzd2

        rho0 = jnp.array(rho0u+rho0d)
        # print('rho0 shape', rho0.shape)
        # print('sigma1/2/3 shapes', sigma1.shape, sigma2.shape, sigma3.shape)
        sumsigma = sigma1+sigma2+sigma3
        # print('sumsigma shape', sumsigma.shape)
        #sum the sigma contributions
        rhosig = jnp.stack([rho0, sigma1+sigma2+sigma3], axis=1)
        # calculate the "custom" energy with rho -- THIS IS e
        # cast back to np.array since that's what pyscf works with
        # pass as tuple -- (rho, sigma)
        #epsilon here
        input_arr = jnp.stack([rho0u, rho0d, sigma1, sigma2, sigma3], axis=1)
        exc = jax.vmap(model_epsilon)(input_arr)
        # print('epsilon shape', exc.shape)
        #e here
        exc = jnp.array(exc)/rho0
        # exc = exc[jnp.newaxis, :]
        # print('exc shape', exc.shape)
        v1_f = jax.grad(model_epsilon)
        v1 = jax.vmap(v1_f)(input_arr)
        #vrho = vrho_up, vrho_down
        vrho = jnp.vstack((v1[:, 0], v1[:, 1]))
        #vsigma = vsigma1, vsigma2, vsigma3
        vsigma = jnp.vstack((v1[:, 2], v1[:, 3], v1[:, 4]))
        vxc = (vrho, vsigma)
        # print('vrho shape', vrho.shape)
        # print('vsigma shape', vsigma.shape)
        v2_f = jax.hessian(model_epsilon)
        v2 = jax.vmap(v2_f)(input_arr)
        # print('v2 shape', v2.shape)
        #v2rho2 = (v2rhou2, v2rhoud, v2rhod2)
        v2rho2 = jnp.vstack((v2[:, 0, 0], v2[:, 0, 1], v2[:, 1, 1]))
        #v2rhosigma is six-part = (u,1),(u,2),(u,3),(d,1),(d,2),(d,3)
        v2rhosigma = jnp.vstack((v2[:, 0, 2], v2[:, 0, 3], v2[:, 0, 4], v2[:, 1, 2], v2[:, 1, 3], v2[:, 1, 4]))
        #v2sigma2 is also six-part
        v2sigma2 = jnp.vstack((v2[:, 2, 2], v2[:, 2, 3], v2[:, 2, 4], v2[:, 3, 3], v2[:, 3, 4], v2[:, 4, 4]))
        # print('v2rho2 shape', v2rho2.shape)
        # print('v2rhosigma shape', v2rhosigma.shape)
        # print('v2sigma2 shape', v2sigma2.shape)
        v2lapl2 = None
        vtau2 = None
        v2rholapl = None
        v2rhotau = None
        v2lapltau = None
        v2sigmalapl = None
        v2sigmatau = None
        # 2nd order functional derivative
        fxc = (v2rho2, v2rhosigma, v2sigma2, v2lapl2, vtau2, v2rholapl, v2rhotau, v2lapltau, v2sigmalapl, v2sigmatau)
        # 3rd order
        kxc = None
        TRANSPOSE = True
        if TRANSPOSE:
            vxc = [i.T for i in vxc]
            fxc = [i.T for i in fxc if type(i) == type(jnp.array([1]))]


    return exc, vxc, fxc, kxc

# %%
#generate random-weight networks
rw_fx = net.GGA_FxNet_sigma(depth=3, nodes=16, seed=92017)
rw_fc = net.GGA_FcNet_sigma(depth=3, nodes=16, seed=92017)
rw_xc = xc.RXCModel_GGA(xnet = rw_fx, cnet = rw_fc)
OVERWRITE_EVAL_XC = partial(local_eval_xc_gga_j2, xcmodel=rw_xc)
GRID_LEVEL = 1
MAX_SCF_STEPS = 25
results = {idx: 0 for idx in range(len(traj))}
for idx, sys in enumerate(traj):
    atstr = ''
    for aidx, sysat in enumerate(sys.get_chemical_symbols()):
        atstr += f"{sysat} {sys.positions[aidx][0]} {sys.positions[aidx][1]} {sys.positions[aidx][2]}\n"
    mol = gto_ad.Mole(atom=atstr, charge=sys.info.get('charge', 0), spin=sys.info.get('spin', 0))
    mol.build()
    #I set this to suppose 32GB of RAM. 
    #If the local memory usage reaches this max_memory value, the SCF cycles are broken down into sub-loops over small sections of the grid that take *forever* to get through
    mol.max_memory = 32000
    print("Beginning calculation...")
    print(f"{idx} -- {sys.symbols}/{sys.get_chemical_formula()}")
    # if sys.get_chemical_formula() != 'H':
    if sys.info.get('spin', 0) == 0:
        print("SPIN 0 -> RKS")
        mf = dft_ad.RKS(mol)
        mf.grids.level = GRID_LEVEL
        mf.max_cycle = MAX_SCF_STEPS
        mf.define_xc_(OVERWRITE_EVAL_XC, 'GGA')
        mf.kernel()
    else:
        print("NONZERO SPIN -> UKS")
        mf = dft_ad.UKS(mol)
        mf.grids.level = GRID_LEVEL
        mf.max_cycle = MAX_SCF_STEPS
        mf.define_xc_(OVERWRITE_EVAL_XC, 'GGA')
        mf.kernel()
    results[idx] = (mf.e_tot, mf.converged)
    print(f"Results: CONVERGED = {mf.converged}, ENERGY = {mf.e_tot}")
# Out:
# Beginning calculation...
# 0 -- FNH3/H3FN
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -153.016352700298
# Results: CONVERGED = True, ENERGY = -153.01635270029846
# Beginning calculation...
# 1 -- F/F
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -97.4288601354338
# Results: CONVERGED = True, ENERGY = -97.42886013543381
# Beginning calculation...
# 2 -- NH3/H3N
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -55.4136748617568
# Results: CONVERGED = True, ENERGY = -55.413674861756846
# Beginning calculation...
# 3 -- Li2/Li2
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -14.5544510346765
# Results: CONVERGED = True, ENERGY = -14.554451034676548
# Beginning calculation...
# 4 -- CLiH3Li2/CH3Li3
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -60.9997484399142
# Results: CONVERGED = True, ENERGY = -60.999748439914214
# Beginning calculation...
# 5 -- CLiH3/CH3Li
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -46.3793332033898
# Results: CONVERGED = True, ENERGY = -46.37933320338983
# Beginning calculation...
# 6 -- F/F
# NONZERO SPIN -> UKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -97.6902080510096  <S^2> = 0.75  2S+1 = 2
# Results: CONVERGED = True, ENERGY = -97.69020805100962
# Beginning calculation...
# 7 -- K/K
# NONZERO SPIN -> UKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -592.445062345202  <S^2> = 0.75000045  2S+1 = 2.0000004
# Results: CONVERGED = True, ENERGY = -592.4450623452022
# Beginning calculation...
# 8 -- KF/FK
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
# converged SCF energy = -690.41200520415
# Results: CONVERGED = True, ENERGY = -690.41200520415
# Beginning calculation...
# 9 -- NHCHC2H2CO3NCH4C2OH4/C7H12N2O4
# SPIN 0 -> RKS
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute coords because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute exp because it is not JSON-serializable
#   warnings.warn(msg)
# /home/awills/anaconda3/envs/pyscfad/lib/python3.10/site-packages/pyscf/gto/mole.py:1293: UserWarning: Function mol.dumps drops attribute ctr_coeff because it is not JSON-serializable
#   warnings.warn(msg)
